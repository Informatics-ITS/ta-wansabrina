# %% [markdown]
# # HIERARCHICAL + CAPTIONING

# %%
# !pip install transformers datasets
# Out:
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %% [markdown]
# ## Cleaning Test Data

# %%
import pandas as pd

csv_path = "/kaggle/input/roco-brain/test/kaggle/working/testdata.csv"
output_path = "/kaggle/working/cleaned_testdata.csv"

keywords = [
    "MRI", "magnetic resonance imaging", "CT", "computed tomography",
    "left", "right", "normal", "abnormal", "T2", "T2-weighted", "weighted",
    "T1", "flair", "axial", "sagittal", "coronal", "tumor", "lesion"
]

df = pd.read_csv(csv_path)

def contains_keywords(caption, keywords):
    if pd.isnull(caption):
        return False
    return any(keyword.lower() in caption.lower() for keyword in keywords)

filtered_df = df[df['caption'].apply(lambda x: contains_keywords(x, keywords))]

print(f"Original number of rows: {len(df)}")
print(f"Filtered number of rows: {len(filtered_df)}")

filtered_df.to_csv(output_path, index=False)

print(f"Filtered data saved to {output_path}.")
# Out:
# Original number of rows: 333
# Filtered number of rows: 313
# Filtered data saved to /kaggle/working/cleaned_testdata.csv.

# %% [markdown]
# ## Hierarchical Classification Logic

# %%
from transformers import AutoImageProcessor, AutoModelForImageClassification
import torch
from PIL import Image

def load_model_and_processor(model_name):
    """
    Load a model and its corresponding processor.

    Args:
        model_name (str): Name of the model to load.

    Returns:
        tuple: A tuple containing the processor and the model.
    """
    processor = AutoImageProcessor.from_pretrained(model_name)
    model = AutoModelForImageClassification.from_pretrained(model_name)
    return processor, model

model_names = {
    "plane": "bombshelll/swin-brain-plane-classification",
    "modality": "bombshelll/swin-brain-modality-classification",
    "abnormality": "bombshelll/swin-brain-abnormalities-classification",
    "tumor_type": "bombshelll/swin-brain-tumor-type-classification",
    "location": "bombshelll/swin-brain-abnormality-location-classification"
}

models_and_processors = {
    name: load_model_and_processor(model_name)
    for name, model_name in model_names.items()
}

plane_processor, plane_model = models_and_processors["plane"]
modality_processor, modality_model = models_and_processors["modality"]
abnormality_processor, abnormality_model = models_and_processors["abnormality"]
tumor_type_processor, tumor_type_model = models_and_processors["tumor_type"]
location_processor, location_model = models_and_processors["location"]

# %%
def inference_classification(processor, model, image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = processor(image, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
        logits = outputs.logits
        predicted_class_idx = logits.argmax(-1).item()
        predicted_label = model.config.id2label[predicted_class_idx]
    return predicted_label

# %%
def hierarchical_classification(image_path):
    """
    Perform multilevel classification on an image.

    Steps:
    1. Classify the plane (e.g., axial, coronal, sagittal).
    2. Classify the modality (e.g., MRI, CT) and sequence (e.g., T1, T2, FLAIR).
    3. Classify the abnormality status (e.g., normal, lesion, tumor).
    4. If tumor, classify the location of the tumor and then the tumor type.
    """
    results = {}

    # Step 1: Plane Classification
    plane_label = inference_classification(plane_processor, plane_model, image_path)
    results["Plane"] = plane_label
    print(f"Plane Classification: {plane_label}")

    # Step 2: Modality Classification
    modality_label = inference_classification(modality_processor, modality_model, image_path)

    modality_parts = modality_label.split(maxsplit=1)
    if len(modality_parts) > 1:
        results["Modality"] = modality_parts[0]
        results["Sequence"] = modality_parts[1]
        print(f"Modality: {modality_parts[0]}")
        print(f"Sequence: {modality_parts[1]}")
    else:
        results["Modality"] = modality_parts[0]
        results["Sequence"] = None
        print(f"Modality: {modality_parts[0]}")

    # Step 3: Abnormality Status Classification
    abnormality_label = inference_classification(abnormality_processor, abnormality_model, image_path)
    results["Abnormality Status"] = abnormality_label
    print(f"Abnormality Status Classification: {abnormality_label}")

    # Step 4: If tumor, classify the location and then the tumor type
    if abnormality_label == "tumor":
        location_label = inference_classification(location_processor, location_model, image_path)
        results["Abnormality Location"] = location_label
        print(f"Abnormality Location Classification: {location_label}")

        tumor_type_label = inference_classification(tumor_type_processor, tumor_type_model, image_path)
        results["Tumor Type"] = tumor_type_label
        print(f"Tumor Type Classification: {tumor_type_label}")

    return results

# %% [markdown]
# ## Inference & Evaluate Hierarchical Classification

# %%
def evaluate_hierarchical_classification(keywords, caption):
    import math

    relevant_labels = {
        "plane": {"axial", "sagittal", "coronal"},
        "modality_and_sequence": {
            "ct", "computed tomography", "mri", "magnetic resonance imaging", "magnetic resonance image",
            "t1", "t1-weighted", "t1w", "t2", "t2-weighted", "t2w", "flair",
        },
        "abnormality": {"normal", "non-abnormal", "lesion", "tumor"},
    }

    synonyms = {
        "t1": {"t1", "t1-weighted", "t1w"},
        "t2": {"t2", "t2-weighted", "t2w"},
        "ct": {"ct", "computed tomography"},
        "mri": {"mri", "magnetic resonance imaging", "magnetic resonance image"},
        "lesion": {"lesion", "lesions"},
        "tumor": {"tumor", "tumour"},
    }

    synonyms = {key.lower(): {term.lower() for term in values} for key, values in synonyms.items()}

    def preprocess_full_text(text):
        text = text.lower()
        text = text.replace("magnetic resonance imaging", "mri")
        text = text.replace("magnetic resonance image", "mri")
        text = text.replace("computed tomography", "ct")
        words = text.replace("-", " ").split()
        return [word.strip("().,") for word in words]

    def standardize_word(word):
        word = word.lower()
        for key, variations in synonyms.items():
            if word in variations:
                return key
        return word

    def split_compound_keywords(keywords):
        split_keywords = set()
        for keyword in keywords:
            if " " in keyword:
                split_keywords.update(keyword.split())
            else:
                split_keywords.add(keyword)
        return split_keywords

    caption_words = preprocess_full_text(caption)
    caption_set = set(standardize_word(word) for word in caption_words)
    processed_keywords = split_compound_keywords(
        set(standardize_word(word) for word in keywords)
    )

    relevant_keywords = set()
    correct_matches = set()
    category_correct_matches = {category: set() for category in relevant_labels}

    for category, label_set in relevant_labels.items():
        standardized_label_set = {standardize_word(label) for label in label_set}
        matched_terms = standardized_label_set.intersection(caption_set)
        relevant_keywords.update(matched_terms)
        predicted_terms = processed_keywords.intersection(standardized_label_set)

        correct_category_matches = predicted_terms.intersection(matched_terms)
        correct_matches.update(correct_category_matches)
        category_correct_matches[category].update(correct_category_matches)

    if not relevant_keywords:
        similarity_score = math.nan
    else:
        similarity_score = (len(correct_matches) / len(relevant_keywords)) * 100

    result_details = {
        "Actual Caption": caption,
        "Keyword Hasil Klasifikasi": keywords,
        "Keywords di caption yang relevan dengan hasil klasifikasi": relevant_keywords,
        "Keyword hasil klasifikasi yang relevan dengan caption": correct_matches,
        "Hasil klasifikasi yang benar": correct_matches,
        "Category-wise Matches": category_correct_matches,
    }

    return similarity_score, result_details

# %%
def inference_and_evaluation(data, image_folder):
    similarity_scores = []

    for index, row in data.iterrows():
        image_name = row['name']
        actual_caption = row['caption']
        image_path = os.path.join(image_folder, image_name)

        print(f"Sample {index + 1}/{len(data)}")
        predicted_labels = hierarchical_classification(image_path)

        predicted_keywords = set(value for value in predicted_labels.values() if value is not None)

        similarity_score, result_details = evaluate_hierarchical_classification(predicted_keywords, actual_caption)

        print(f"Actual Caption: {result_details['Actual Caption']}")
        print(f"Keyword Hasil Klasifikasi: {result_details['Keyword Hasil Klasifikasi']}")
        print(f"Keywords di caption yang relevan dengan hasil klasifikasi: {result_details['Keywords di caption yang relevan dengan hasil klasifikasi']}")
        print(f"Keyword hasil klasifikasi yang relevan dengan caption: {result_details['Keyword hasil klasifikasi yang relevan dengan caption']}")
        print(f"Hasil klasifikasi yang benar: {result_details['Hasil klasifikasi yang benar']}")
        print(f"Similarity Score: {similarity_score if not math.isnan(similarity_score) else 'NaN'}")
        print(f"------------------------------------------")

        if not math.isnan(similarity_score):
            similarity_scores.append(similarity_score)

    average_similarity = sum(similarity_scores) / len(similarity_scores) if similarity_scores else 0
    print(f"Average Similarity Score (excluding NaN): {average_similarity:.2f}%")
    return similarity_scores, average_similarity

# %%
import math
import os

csv_path = "/kaggle/working/cleaned_testdata.csv"
image_folder = "/kaggle/input/roco-brain/test/kaggle/working/test_images"
data = pd.read_csv(csv_path)

similarity_scores = inference_and_evaluation(data, image_folder)
# Out:
# Sample 1/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain magnetic resonance imaging (MRI) after gadolinium injection showed an image in the axial (FLAIR sequence) showing hyper-intensity lesions in the white matter of the frontal lobes. There is no signal abnormality of the cortex. Note that there is no mass effect on the ventricular cavities or midline structures.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri', 'flair', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri', 'flair', 'axial'}
# Hasil klasifikasi yang benar: {'lesion', 'mri', 'flair', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 2/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Twelve-year-old boy presented with nasopharyngeal angiofi broma diagnosed with unilateral meningo-ophthalmic artery anomaly. Computed tomography scan shows midline nasopharyngeal angiofi broma (black arrow), with prominent right-side infiltration into the infratemporal fossa (white arrow).
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 3/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  An HC with a diameter of 0.37 cm in the left hippocampus is noted in the T1-weighted image at the level of the hippocampus
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 4/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  PMMR of hypoxic brain changes. Axial T2-weighted PMMR image through a fetal post mortem brain, showing an example of typical low signal change in the basal ganglia which may be associated with hypoxia. Conventional PMMR cannot currently distinguish antemortem from postmortem hypoxic change
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'axial'}
# Hasil klasifikasi yang benar: {'t2', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 5/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  CT scan of the brain showing a solitary metastasis, 5x4 cm, in the right occipital lobe, with some extension to the parietal lobe. Note the heterogeneic appearance of the metastasis and the surrounding brain edema
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 6/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Axial T2-weighted MR image showing an “angel wing appearance” in the brainstem (black arrows).
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'axial'}
# Hasil klasifikasi yang benar: {'t2', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 7/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Magnetic resonance imaging brain axial section T1-weighted image showing large sella-suprasellar mass
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 33.33333333333333
# ------------------------------------------
# Sample 8/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  CTP post-processed image.The patient was a 48-year-old man, with no history of hypertension, diabetes, or heart disease. The onset time was 4 hours, with a lesion detected in the right temporal lobe. The baseline NIHSS score was 15. After thrombolytic therapy, the 24-hour NIHSS score was 9. Red areas represent the infarct core. Green areas represent the penumbra. R: Right; L: left; CTP: computed tomography perfusion; NIHSS: National Institution of Health Stroke Scale.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'lesion'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion'}
# Hasil klasifikasi yang benar: {'lesion'}
# Similarity Score: 50.0
# ------------------------------------------
# Sample 9/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI of the brain showed a large mass in the left frontal area T2/FLAIR. Mild surrounding vasogenic edema and mass effect.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 10/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: right
# Tumor Type Classification: Meduloblastoma
# Actual Caption:  Initial MRI of the brain with and without contrast.A large right frontal lobe intra-axial mass with mass effect upon the right ventricular system and a leftward midline shift of approximately 1.3 cm is shown.
#
# Keyword Hasil Klasifikasi: {'right', 'MRI', 'Meduloblastoma', 'tumor', 'T2 FLAIR', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 11/313
# Plane Classification: sagittal
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Axial section through the brainstem at the nerve root entry zone of the left trigeminal nerve with an illustration of the location of the 50% isodose line for gamma knife radiation treatment planning. This was the treatment location for the first and second gamma knife procedures.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 12/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain magnetic resonance imaging, T1-weighted image showing ring-like enhancement of the active plaque
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 50.0
# ------------------------------------------
# Sample 13/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain axial T2W magnetic resonance imaging at the level of the midbrain. High signal around the Aqueduct of Sylvius (arrow).
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 't2', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 't2', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 't2', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 14/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI brain T2 axial FLAIR sequence showed hyperintensities in the left thalamus and right mesial occipital lobe.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 't2', 'flair', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 't2', 'flair', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 't2', 'flair', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 15/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI axial T2-weighted image identifying increased signal intensity at the left temporal lobe (arrow). Image contrast brightened.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 't2', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 't2', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 't2', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 16/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Magnetic resonance imaging brain (three-dimensional constructive interference in steady-state sequences) showing the anterior inferior cerebellar artery (black arrow) abutting the root entry zone of the facial nerve (white arrow) on the right side with no evidence of any mass lesions
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 17/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI of the brain: T1 coronal post-contrast sequence demonstrating faint bilateral optic nerve enhancement.
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'coronal', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'coronal', 'mri'}
# Hasil klasifikasi yang benar: {'coronal', 'mri'}
# Similarity Score: 66.66666666666666
# ------------------------------------------
# Sample 18/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain MRI of FLAIR in 25 year old female with eclampsia demonstrating involvement of frontal and occipital lobes along with bilateral basal ganglion
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'flair', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'flair', 'mri'}
# Hasil klasifikasi yang benar: {'flair', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 19/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: normal
# Actual Caption:  Pre-operative Magnetic Resonance imaging of brain showing hypothalamic hamartoma
#
# Keyword Hasil Klasifikasi: {'normal', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 20/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  One week after a febrile illness, a 55 year old man developed neurogenic dysphagia accompanied by ataxia and drowsiness. Clinical examination revealed ophthalmoplegia, cerebellar signs and sluggish deep tendon reflexes. MRI of the brain showed a single hyperintense lesion in the pons, On T2 W images which moderately enhanced with contrast. He rapidly recovered following intravenous steroids
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 't2', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 't2', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 't2', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 21/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Across-group aPFC activity (local maxima, 30 62 −4) for motivationally incongruent versus congruent trials within Brodmann area 10.The image is thresholded at P < 0.05 (uncorrected) for visualization purposes. No other clusters reached significance for the comparison between incongruent and congruent responses in the whole group (that is, none reached whole-brain FWE correction). aPFC activity did not differ between substance groups.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 22/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain edema. Coronal sonogram in a 7-day-old infant with group B streptococcus meningitis shows generalized edema with compression of lateral ventricles and sulci and diffuse increased heterogeneity of the cerebral hemispheres
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'coronal'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 23/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI Brain (T2w image) scan shows residual tumor.
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'tumor', 't2', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'mri'}
# Hasil klasifikasi yang benar: {'t2', 'mri'}
# Similarity Score: 66.66666666666666
# ------------------------------------------
# Sample 24/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Axial brain ct showing anterior falx calification
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 25/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  68-year-old man with a dural arteriovenous fistula of the superior sagittal sinus. Anterior-posterior image of distal right external carotid artery injection demonstrating supply to the superior sagittal sinus fistula from a large superficial temporal artery branch as well as right middle meningeal artery branches. Note filling of the superior sagittal sinus as well as several cortical veins (arrows) indicating the presence of cortical venous reflux.
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'sagittal'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 26/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Astrocitoma
# Actual Caption:  T1WI shows hyperintense mass in the region of foramen of Monro extending superiorly into the frontal lobe
#
# Keyword Hasil Klasifikasi: {'MRI', 'tumor', 'T2 FLAIR', 'Astrocitoma', 'left', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 27/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Skull radiograph of patient 1 taken on 13 days of age. White arrow indicates the calcification at right parietal region.
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 28/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Diffusion weighted scan of the magnetic resonance imaging brain showing no restriction of diffusion suggestive of lesions being vasogenic edema rather than infarcts
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 29/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  CT scan of the brain 48-hours after the head injury.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 30/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T1
# Abnormality Status Classification: normal
# Actual Caption:  Axial T1W MRI without contrast shows hyperintensities in the parietal sulci indicating leptomeningeal involvement.
#
# Keyword Hasil Klasifikasi: {'T1', 'normal', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t1', 'mri', 'axial'}
# Hasil klasifikasi yang benar: {'t1', 'mri', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 31/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Meduloblastoma
# Actual Caption:  MRI scan showing a multifocal intracranial mass, with lesions in the anterior part of the corpus callosum, extending inferiorly on the septum pellucidum and columns of the fornices, adjacent foci of subependymal enhancing tumour in the heads of the caudate nuclei and anterior part of the left thalamus, tumour in the pineal region, inferior third ventricle and roof of the fourth ventricle.
#
# Keyword Hasil Klasifikasi: {'MRI', 'Meduloblastoma', 'tumor', 'T2 FLAIR', 'left', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'tumor', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'tumor', 'mri'}
# Hasil klasifikasi yang benar: {'tumor', 'mri'}
# Similarity Score: 66.66666666666666
# ------------------------------------------
# Sample 32/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Computerized tomography brain axial view showing cyst in the pineal region
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'axial'}
# Hasil klasifikasi yang benar: {'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 33/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI scan of the brain showing extensive encephalomalacia in the left cerebral hemisphere
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 34/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  CT brain (axial view) showing a hypodense lesion in the right frontal lobe
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'ct', 'axial'}
# Hasil klasifikasi yang benar: {'lesion', 'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 35/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  CT brain—showing cortical venous thrombosis
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 36/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI scan with moderate degree of enhancement at the base of the skull, affecting the right occipital condyle and part of the right side of the basilar bone.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 37/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Axial contrast-enhanced T1-weighted image showed a ring enhancement lesion in right temporooccipital lobe
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 't1', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'axial'}
# Hasil klasifikasi yang benar: {'lesion', 'axial'}
# Similarity Score: 66.66666666666666
# ------------------------------------------
# Sample 38/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:   Magnetic resonance imaging (flair image) showing left frontal focal area of acute ischemic infarction (arrow), and right parietal periventricular white matter old infarction (arrow)
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'flair', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'flair', 'mri'}
# Hasil klasifikasi yang benar: {'flair', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 39/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Noncontrast axial cranial CT revealing left temporoparietal acute extradural hematoma
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 40/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Neurofibromatosis Type 2. A 34-year-old man with mild hearing loss in the left ear. Axial computed tomography (parenchymal window) of the temporal bone shows extensive choroid plexus calcifications within both atria (arrows) extending into the left temporal horn (arrowhead)
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 41/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain MRI [Siemens MAGNETOM Symphony 1.5T, T2WI (TR/TE = 1,300/69 ms)] showing mild diffuse atrophy and punctate increased signals of the frontal white matter.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 42/313
# Plane Classification: coronal
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Axial computerised tomography scans of the orbits showing absence of the greater wing of sphenoid (white asterix), with herniation of brain parenchyma into the left orbit (long white arrow), esotropia and kinking of the left optic nerve (short white arrow)
#
# Keyword Hasil Klasifikasi: {'CT', 'coronal', 'lesion'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 43/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Axial brain ct showing bilateral symmetrical basal ganglial calcification
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 44/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Head MRI showing multiple occupations in the right temporal, apical, and occipital lobes and in the corpus callosum
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 45/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  CT scan of Temporal bone. The thick arrow shows the bony discontinuity in the left temporal bone.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 46/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  The axial view of the CT scan of the brain revealed a hypodensity mass (white arrow) in the left frontal lobe.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 47/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI Axial T2 FLAIR section showing symmetrical hyperintense lesions involving subcortical and cortical locations of the bilateral frontal and parietal lobes
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'flair', 'axial', 't2', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'flair', 'axial', 't2', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'flair', 'axial', 't2', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 48/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Arachnoidal cysts. MRI Scan of the brain. Coronar, T2-weighted. Cerebellar dysplasia is seen on the right side. The arrow indicates a large arachnoidal cyst.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'mri'}
# Hasil klasifikasi yang benar: {'t2', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 49/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain magnetic resonance. The figure shows subcortical hyperintense lesions on T2-weighted sequences, with different characteristics. One draws the subcortical white matter with preservation of U fibers, at the left parietal-occipital, and the other has rounded morphology and was located in right temporal white matter. None of them suggests hemorrhagic transformation
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2', 'lesion'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'lesion'}
# Hasil klasifikasi yang benar: {'t2', 'lesion'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 50/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain MRI. No distant metastases
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 51/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  CT scan of the brain showing decompressed lateral ventricleswith some blood in the occipital horns (arrows) and extra-axial fluid collection. Tip of the EVD is seen in the lateral ventricle
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 52/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Magnetic resonance imaging scan of the brain showing a well-defined round to oval space occupying lesion with marked peri-lesional white matter edema in the right fronto-parietal lobe
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 53/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  CT scan of the brain (axial sequence) shows an area of hyperdensity in the right frontal lobe suggestive of intracerebral hemorrhage (arrow) in a 67 year old woman who underwent right carotid endarterectomy (CEA) for the treatment of a 95 % right ICA stenosis. The patient post-operatively developed headache, photophobia and intermittent dizziness. This CT brain was done almost 24 h after the CEA. Systolic blood pressure was in the 170 s mm Hg and difficult to control as after CEA there was thought to be a clamp injury to the right carotid artery bulb. However, the patient did well clinically and at her 3 month follow up office visit, she had no residual neurological deficits
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 54/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Neurocitoma
# Actual Caption:  Magnetic resonance angiogram of the brain demonstrating normal patency of bilateral internal carotid arteries, anterior cerebral arteries, middle cerebral arteries, posterior cerebral arteries, and vertebrobasilar arteries.
#
# Keyword Hasil Klasifikasi: {'Neurocitoma', 'MRI', 'tumor', 'T2 FLAIR', 'coronal', 'left'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'normal'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 55/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Coronal non-contrast image from brain CT assessment of frequent falls.Bilateral bands of hyperdensity that do not conform to insertions of extra-ocular muscles, are consistent with prior bilateral scleral bands for treatment of retinal detachment. However, characteristic concavity at site of banding is not seen in this case.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'coronal'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 50.0
# ------------------------------------------
# Sample 56/313
# Plane Classification: sagittal
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  CT-scan of the temporal bone. Good aeration. Exposed malleus-incus-conglomerate. AP: atresia plate. (Thanks to Prof. Dr. med. E. Hofmann, director of the department for diagnostic and interventional neuroradiology, Klinikum Fulda gAG)
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 57/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Meningioma
# Actual Caption:  Axial T2WI shows fluid-fluid level within the mass and marked compression over the left cerebral peduncle of midbrain
#
# Keyword Hasil Klasifikasi: {'MRI', 'tumor', 'T2 FLAIR', 'Meningioma', 'left', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'axial'}
# Hasil klasifikasi yang benar: {'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 58/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Case 1. Axial FLAIR MRI: cortical-subcortical hyperintense lesions in parietal-occipital regions and in the posterior lateral left putamen.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'flair', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'flair', 'axial'}
# Hasil klasifikasi yang benar: {'lesion', 'flair', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 59/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Anatomical landmarks of orbitofrontal lobe (OFL) in lateral sagittal sections
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'sagittal'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 60/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Brain CT revealing bilateral subacute frontoparietal subdural hematomas, measuring 10mm on the left and 8mm on the right, with associated local sulcal effacement.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 61/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  T2-weighted axial MRI of the brain showing no obvious abnormality
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 't2', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 't2', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 't2', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 62/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI brain T2W axial image showing hyperintense left parietal lesion.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 't2', 'lesion', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 't2', 'lesion', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 't2', 'lesion', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 63/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI brain with FLAIR axial cut, done 3 months after the initial MRI showing resolution of the hyperintense signals seen at presentation
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 'flair', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 'flair', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 'flair', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 64/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Computed tomography imaging revealed hyperdense foci, corresponding to massive calcifications in the nuclei of the base of the brain, in the thymuses, as well as subcortical in the white matter of both frontal lobes
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 65/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Reduction in dimensions of the cystic mass, parietal discontinuity (arrow) and voluminous ascites that was not identified at the previous study (asterisks) performed eight days ago.
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 66/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T1
# Abnormality Status Classification: lesion
# Actual Caption:  Axial T1-weighted cranial MR image shows hemorrhages in temporal lobe
#
# Keyword Hasil Klasifikasi: {'lesion', 'T1', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t1', 'axial'}
# Hasil klasifikasi yang benar: {'t1', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 67/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T1
# Abnormality Status Classification: lesion
# Actual Caption:  Brain MRI T1-WI axial plane of a patient with ephedrone encephalopathy: symmetrical signal increase in globi pallidi.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T1', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t1', 'mri', 'axial'}
# Hasil klasifikasi yang benar: {'t1', 'mri', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 68/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Postoperative brain computed tomography scan 6 weeks after abscess drainage and antibiotic therapy confirms obvious shrinkage of cavities and exvacuum ventriculomegaly.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 69/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain MRI Angiography. Normal.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'normal', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 50.0
# ------------------------------------------
# Sample 70/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Meduloblastoma
# Actual Caption:  Control brain MRI 3D Axial T1 with gadolinium 10 months after surgery and prolonged antibiotic treatment, shows complete regression of the cerebellar and cerebellopontine angle abscesses, leaving on the site a thickened meningeal scar.
#
# Keyword Hasil Klasifikasi: {'MRI', 'Meduloblastoma', 'tumor', 'T2 FLAIR', 'left', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 33.33333333333333
# ------------------------------------------
# Sample 71/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Absence of acute brain parenchymal lesion upon initial computed tomography of the brain.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'lesion'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'lesion'}
# Hasil klasifikasi yang benar: {'ct', 'lesion'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 72/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Noncontrasted CT brain showing bifrontal lestion with area of focal calcification
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 73/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI-T2 Flair showing hyperintensity extending from posterior frontal, parietal causing mass effect compressing the midline and posterior corpus callosum.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2', 'flair', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'flair', 'mri'}
# Hasil klasifikasi yang benar: {'t2', 'flair', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 74/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Mechanisms of recovery of injured fornical crus determined by diffusion tensor tractography.①Mechanism 1: Recovery through the neural tract from an injured fornical crus to the medial temporal lobe via the normal pathway of the fornical crus. ② Mechanism 2: Recovery through the neural tract originating from an ipsi-lesional fornical body connected to the ipsi-lesional medial temporal lobe via the splenium of the corpus callosum. ③Mechanism 3: Recovery through the neural tract from the ipsi-lesional fornical body extending to the contra-lesional medial temporal lobe via the splenium of the corpus callosum. ④ Mechanism 4: Recovery through the neural tract originating from the ipsi-lesional fornical column connected to the ipsi-lesional medial temporal lobe. ⑤Mechanism 5: Recovery through the nerve tract originating from the contra-lesional fornical column connected to the ipsi-lesional medial temporal lobe via the contra-lesional medial temporal lobe and the splenium of the corpus callosum.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'normal'}
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: 0.0
# ------------------------------------------
# Sample 75/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T1
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Meduloblastoma
# Actual Caption:  Axial T2 Large area of porencephaly in the left frontal and parietal lobes with compensatory dilatation of the lateral ventricle.
#
# Keyword Hasil Klasifikasi: {'MRI', 'Meduloblastoma', 'tumor', 'coronal', 'left', 'T1'}
# ...
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'normal', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'mri'}
# Similarity Score: 66.66666666666666
# ------------------------------------------
# Sample 289/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Brain magnetic resonance imaging revealing corpus callosum thinning (marked as an arrow).
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 290/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Meningioma
# Actual Caption:  Chasing leads on brain tumors.Information on what causes brain tumors is fragmented; however, new data may tie together clues about lead exposure and a predisposition to develop meningioma.
#
# Keyword Hasil Klasifikasi: {'MRI', 'tumor', 'T2 FLAIR', 'Meningioma', 'left', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 291/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Post-operative CT (after hemicraniectomy) day 2. The white arrows highlight the hypodense regions of brain parenchyma in the posterior circulation which is tissue at risk for subsequent ischemic injury.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 292/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Case 4 – Magnetic resonance imaging of brain (sagittal section) shows a cystic lesion in the suprasellar cistern (outlined by arrows) suggestive of craniopharyngioma
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri', 'sagittal'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri', 'sagittal'}
# Hasil klasifikasi yang benar: {'lesion', 'mri', 'sagittal'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 293/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: normal
# Actual Caption:  Axial nonenhanced computed tomography image shows hemorrhagic contusion areas in the frontal lobes bilaterally as foci of hyperdensity involving the grey matter and subcortical white matter and hyperdensities filling the subarachnoid space due to subarachnoid hemorrhage in the anterior interhemispheric fissure and sulci in the frontal lobes (arrow). In addition, intraventricular hemorrhage is seen (dashed arrow)
#
# Keyword Hasil Klasifikasi: {'normal', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 294/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: normal
# Actual Caption:  Axial brain MRI GRE sequence showing a large area of susceptibility artifact in the posterior lateral left thalamus, consistent with blood products.
#
# Keyword Hasil Klasifikasi: {'normal', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 295/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Magnetic resonance imaging of a 9-cm jugular paraganglioma invading the skull base, carotid vessels, and the mastoid part of the temporal bone.
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 296/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Axial FLAIR sequence shows well-circumscribed subcortical hypointense cystic lesion in bilateral anterior temporal lobe.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'flair', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'flair', 'axial'}
# Hasil klasifikasi yang benar: {'lesion', 'flair', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 297/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Fluorescein fundus angiogram of right eye with NA-AION, showing location of the watershed zone (arrows, WSZ, vertical dark band) in relation to the optic disc. The watershed zone is passing through the temporal part of the disc and adjacent temporal peripapillary choroid[36]
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 298/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Axial unenhanced brain CT scan, acquired at hospital admission, showing right-sided hyperdensity in the putamen (arrow).
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct', 'axial'}
# Hasil klasifikasi yang benar: {'ct', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 299/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI brain coronal fluid attenuated inversion recovery image showing periventricular hyperintense lesions
#
# Keyword Hasil Klasifikasi: {'lesion', 'MRI', 'coronal', 'T2 FLAIR'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'coronal', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'coronal', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'coronal', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 300/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Axial FLAIR T2-weighted brain MRI showing a sinonasal mass involving the ethmoid/sphenoid sinuses (white arrows) with extension into the right orbit (black arrowhead).
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'mri', 't2', 'flair', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 't2', 'flair', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 't2', 'flair', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 301/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  T2W MRI brain showing classical “Eye of Tiger sign”
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'mri'}
# Hasil klasifikasi yang benar: {'t2', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 302/313
# Plane Classification: coronal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Meningioma
# Actual Caption:  Axial MRI section with T1-weighted sequence with fat suppression after administration of paramagnetic contrast medium. There is high uptake of the contrast medium in the lesions in the cavernous sinus and Meckel’s cave (arrows). High uptake is also observed in the lesion in the hypothalamus (arrowhead).
#
# Keyword Hasil Klasifikasi: {'MRI', 'tumor', 'T2 FLAIR', 'Meningioma', 'coronal', 'left'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 't1', 'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 25.0
# ------------------------------------------
# Sample 303/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Initial brain computed tomography obtained at admission showing a chronic subdural hemorrhage (arrowheads) over both cerebral hemispheres, which compressed the adjacent brain.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 304/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:   Magnetic resonance imaging brain axial T1-weighted contrast-enhancing image demonstrating dramatic improvement in the Fusarium fungal abscess after both surgical evacuation and 7 months of antifungal therapy.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t1', 'mri', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri', 'axial'}
# Hasil klasifikasi yang benar: {'mri', 'axial'}
# Similarity Score: 66.66666666666666
# ------------------------------------------
# Sample 305/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI: hyperintense signal involving the white matter typically in occipital regions.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 306/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MRI post initial procedure which shows small localised soft-tissue lesion in the right fronto-parietal region (measuring up to 1.5 cm) with no extension to the underlying bone.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 307/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: tumor
# Abnormality Location Classification: left
# Tumor Type Classification: Meningioma
# Actual Caption:  Magnetic resonance image of the brain showing the complex cystic lesion extending from the left hemipons to the thalamus.
#
# Keyword Hasil Klasifikasi: {'MRI', 'tumor', 'T2 FLAIR', 'Meningioma', 'left', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'mri'}
# Hasil klasifikasi yang benar: {'mri'}
# Similarity Score: 50.0
# ------------------------------------------
# Sample 308/313
# Plane Classification: sagittal
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Computed tomography of the brain showing the tip of the arrowhead reaching up to the brainstem
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 309/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  MR T2 axial image showing contusion of the brainstem
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2', 'axial'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2', 'axial'}
# Hasil klasifikasi yang benar: {'t2', 'axial'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 310/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  75-year-old man with amygdala enlargement and Rathke's cleft cyst.Sagittal 11C-methionine (Met) positron emission tomography/CT image showing no 11C-Met uptake in Rathke's cleft cyst, whereas physiological 11C-Met uptake is observed in pituitary gland in anterior part.
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: set()
# Keyword hasil klasifikasi yang relevan dengan caption: set()
# Hasil klasifikasi yang benar: set()
# Similarity Score: NaN
# ------------------------------------------
# Sample 311/313
# Plane Classification: axial
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  T2-weighted brain MRI: Note periventricular hyperintensities in relation with CSF resorption.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'t2'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'t2'}
# Hasil klasifikasi yang benar: {'t2'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 312/313
# Plane Classification: sagittal
# Modality: MRI
# Sequence: T2 FLAIR
# Abnormality Status Classification: lesion
# Actual Caption:  Magnetic resonance image.Preoperative magnetic resonance imaging showed a well-circumscribed, unilocular 18 cm×14 cm×8 cm cystic lesion without skull or brain involvement.
#
# Keyword Hasil Klasifikasi: {'lesion', 'T2 FLAIR', 'MRI', 'sagittal'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'lesion', 'mri'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'lesion', 'mri'}
# Hasil klasifikasi yang benar: {'lesion', 'mri'}
# Similarity Score: 100.0
# ------------------------------------------
# Sample 313/313
# Plane Classification: axial
# Modality: CT
# Abnormality Status Classification: lesion
# Actual Caption:  Cranial computed tomography shows location of ischemic stroke at chronic stage in left occipital lobe (white arrow)
#
# Keyword Hasil Klasifikasi: {'lesion', 'CT', 'axial'}
# Keywords di caption yang relevan dengan hasil klasifikasi: {'ct'}
# Keyword hasil klasifikasi yang relevan dengan caption: {'ct'}
# Hasil klasifikasi yang benar: {'ct'}
# Similarity Score: 100.0
# ------------------------------------------
# Average Similarity Score (excluding NaN): 77.37%

# %% [markdown]
# ## Load Image Captioning Model

# %%
# !pip install transformers datasets

from transformers import VisionEncoderDecoderModel, AutoTokenizer, ViTFeatureExtractor
from PIL import Image
import torch

model_name = "bombshelll/ViT_BioMedBert_Captioning_ROCO"
model = VisionEncoderDecoderModel.from_pretrained(model_name).to("cuda" if torch.cuda.is_available() else "cpu")
tokenizer = AutoTokenizer.from_pretrained(model_name)
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name)

image_path = "/kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg"

image = Image.open(image_path).convert("RGB")
image.show()
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /opt/conda/lib/python3.10/site-packages (4.45.1)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from transformers) (3.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.25.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/conda/lib/python3.10/site-packages (from transformers) (0.20.0)
# Requirement already satisfied: tqdm>=4.27 in /opt/conda/lib/python3.10/site-packages (from transformers) (4.66.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (16.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from datasets) (2.2.2)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.10/site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.6.1,>=2023.1.0 in /opt/conda/lib/python3.10/site-packages (from fsspec[http]<=2024.6.1,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp in /opt/conda/lib/python3.10/site-packages (from datasets) (3.9.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/embeddings', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/encoder']
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/embeddings', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/encoder']
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/embeddings', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/encoder']
# /opt/conda/lib/python3.10/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
import pandas as pd

csv_path = "/kaggle/working/cleaned_testdata.csv"

test_df = pd.read_csv(csv_path)

image_name = "PMC3219482_crg0005-0583-f01.jpg"
actual_caption = test_df.loc[test_df['name'] == image_name, 'caption'].values[0]

device = "cuda" if torch.cuda.is_available() else "cpu"
pixel_values = feature_extractor(images=image, return_tensors="pt").pixel_values.to(device)

model.eval()
with torch.no_grad():
    generated_ids_no_keyword = model.generate(
        pixel_values,
        max_length=80,
        num_beams=4,
        no_repeat_ngram_size=3,
        length_penalty=2.0
    )
# Out:
# /usr/bin/xdg-open: 882: www-browser: not found
# /usr/bin/xdg-open: 882: links2: not found
# /usr/bin/xdg-open: 882: elinks: not found
# /usr/bin/xdg-open: 882: links: not found
# /usr/bin/xdg-open: 882: lynx: not found
# /usr/bin/xdg-open: 882: w3m: not found
# xdg-open: no method available for opening '/tmp/tmpjwda_p0_.PNG'

# %%
caption_no_keyword = tokenizer.decode(generated_ids_no_keyword[0], skip_special_tokens=True)

print("Actual Caption:", actual_caption)

keywords = ["axial", "MRI", "lesion", "T1"]

keyword_prompt = " ".join(keywords)

decoder_input_ids = tokenizer(keyword_prompt, return_tensors="pt").input_ids.to(device)

with torch.no_grad():
    generated_ids_with_keyword = model.generate(
        pixel_values,
        decoder_input_ids=decoder_input_ids,
        max_length=80,
        num_beams=4,
        no_repeat_ngram_size=3,
        length_penalty=2.0
    )

caption_with_keyword = tokenizer.decode(generated_ids_with_keyword[0], skip_special_tokens=True)
print("Generated Caption (No Keyword):", caption_no_keyword)

print("Generated Caption (With Keyword):", caption_with_keyword)
# Out:
# Actual Caption:  Axial MRI of the brain shows solid tumors in the right cerebral peduncle and in the left occipital lobe with surrounding cerebral edema.
#
# Generated Caption (No Keyword): t1 - weighted magnetic resonance image of the brain showing rim enhancing lesion in the left thalamus with surrounding edema.
# Generated Caption (With Keyword): axial mri lesion t1 magnetic resonance imaging of the brain showing enhancing lesion in the left temporal lobe, with surrounding edema.

# %% [markdown]
# ## Inference & Integrate Hierarchical and Captioning

# %%
def inference_and_integrate(data, image_folder, model, tokenizer, feature_extractor, device="cuda"):
    """
    Perform inference for hierarchical classification and integrate the classification results
    into the image captioning process.

    Args:
        data (pd.DataFrame): DataFrame containing 'name' and 'caption' columns.
        image_folder (str): Path to the folder containing test images.
        model: VisionEncoderDecoderModel for generating captions.
        tokenizer: Tokenizer corresponding to the model.
        feature_extractor: Feature extractor corresponding to the model.
        device (str): Device to run the model ('cuda' or 'cpu').

    Returns:
        list: A list containing dictionaries with results for each image.
    """
    results = []

    for index, row in data.iterrows():
        image_name = row['name']
        actual_caption = row['caption']
        image_path = os.path.join(image_folder, image_name)

        print(f"Sample {index + 1}/{len(data)} - Processing {image_name}")
        predicted_labels = hierarchical_classification(image_path)

        predicted_keywords = [value for value in predicted_labels.values() if value is not None]
        print(f"Actual Caption: {actual_caption}")
        print(f"Keyword Hasil Klasifikasi: {predicted_keywords}")

        image = Image.open(image_path).convert("RGB")
        pixel_values = feature_extractor(images=image, return_tensors="pt").pixel_values.to(device)

        model.eval()
        with torch.no_grad():
            generated_ids_no_keyword = model.generate(
                pixel_values,
                max_length=80,
                num_beams=4,
                no_repeat_ngram_size=3,
                length_penalty=2.0
            )
        caption_no_keyword = tokenizer.decode(generated_ids_no_keyword[0], skip_special_tokens=True)
        print(f"Generated Caption (No Keyword): {caption_no_keyword}")

        keyword_prompt = " ".join(predicted_keywords)
        decoder_input_ids = tokenizer(keyword_prompt, return_tensors="pt").input_ids.to(device)

        with torch.no_grad():
            generated_ids_with_keyword = model.generate(
                pixel_values,
                decoder_input_ids=decoder_input_ids,
                max_length=80,
                num_beams=4,
                no_repeat_ngram_size=3,
                length_penalty=2.0
            )
        caption_with_keyword = tokenizer.decode(generated_ids_with_keyword[0], skip_special_tokens=True)
        print(f"Generated Caption (With Keyword): {caption_with_keyword}")
        print(f"------------------------------------------")

        results.append({
            "Image Name": image_name,
            "Actual Caption": actual_caption,
            "Predicted Keywords": predicted_keywords,
            "Caption Without Keywords": caption_no_keyword,
            "Caption With Keywords": caption_with_keyword
        })

    return results

csv_path = "/kaggle/working/cleaned_testdata.csv"
image_folder = "/kaggle/input/roco-brain/test/kaggle/working/test_images"
test_df = pd.read_csv(csv_path)

device = "cuda" if torch.cuda.is_available() else "cpu"

results = inference_and_integrate(test_df, image_folder, model, tokenizer, feature_extractor, device)

results_df = pd.DataFrame(results)
results_df.to_csv("/kaggle/working/inference_and_integration_results.csv", index=False)
# Out:
# Sample 1/313 - Processing PMC3395713_mjhid-4-1-e2012043f2.jpg
# Actual Caption:  Brain magnetic resonance imaging (MRI) after gadolinium injection showed an image in the axial (FLAIR sequence) showing hyper-intensity lesions in the white matter of the frontal lobes. There is no signal abnormality of the cortex. Note that there is no mass effect on the ventricular cavities or midline structures.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): diffusion - weighted magnetic resonance imaging of brain with gadolinium showing multiple small areas of hyperintensity involving the white matter, centrum semiovale, and
# Generated Caption (With Keyword): axial mri t2 flair lesion diffusion - weighted image of brain shows hyperintensity in the splenium of corpus callosum ( arrow ).
# ------------------------------------------
# Sample 2/313 - Processing PMC4278099_JCIS-4-65-g002.jpg
# Actual Caption:  Twelve-year-old boy presented with nasopharyngeal angiofi broma diagnosed with unilateral meningo-ophthalmic artery anomaly. Computed tomography scan shows midline nasopharyngeal angiofi broma (black arrow), with prominent right-side infiltration into the infratemporal fossa (white arrow).
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computed tomography of the brain showing a hypodense, well - defined lesion in the right infratemporal fossa, extending into the infrate
# Generated Caption (With Keyword): axial ct lesion computed tomography of the patient showing a hypodense lesion in the right infratemporal fossa, with extension into the infra
# ------------------------------------------
# Sample 3/313 - Processing PMC3950805_ABR-3-59-g003.jpg
# Actual Caption:  An HC with a diameter of 0.37 cm in the left hippocampus is noted in the T1-weighted image at the level of the hippocampus
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): high - resolution coronal computed tomography scan of the brain showing hypoplastic vermis with fused temporal lobes.
# Generated Caption (With Keyword): coronal mri t2 flair lesion in a child with ephedrone encephalopathy. high - signal intensity signal is seen in the basal ganglia as well as
# ------------------------------------------
# Sample 4/313 - Processing PMC5306347_12024_2016_9821_Fig9_HTML.jpg
# Actual Caption:  PMMR of hypoxic brain changes. Axial T2-weighted PMMR image through a fetal post mortem brain, showing an example of typical low signal change in the basal ganglia which may be associated with hypoxia. Conventional PMMR cannot currently distinguish antemortem from postmortem hypoxic change
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging of brain ( t2 - weighted image ) showing large hyperintense lesion in the left posterior parietal lobe.
# Generated Caption (With Keyword): axial mri t2 flair lesion magnetic resonance imaging of brain in axial section..
# ------------------------------------------
# Sample 5/313 - Processing PMC4912748_40661_2016_28_Fig1_HTML.jpg
# Actual Caption:  CT scan of the brain showing a solitary metastasis, 5x4 cm, in the right occipital lobe, with some extension to the parietal lobe. Note the heterogeneic appearance of the metastasis and the surrounding brain edema
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): axial ct image of the brain shows multiple hypodense subcortical areas ( arrows ) involving both cerebral hemispheres.
# Generated Caption (With Keyword): axial ct lesion axial view at the level of basal ganglia. note that bilateral basal ganglia are hypodense ( arrows ).
# ------------------------------------------
# Sample 6/313 - Processing PMC4274733_poljradiol-79-479-g017.jpg
# Actual Caption:  Axial T2-weighted MR image showing an “angel wing appearance” in the brainstem (black arrows).
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain ( t2 flair ) showing bilateral optic neuritis with hyperintensity in the temporal lobes.
# Generated Caption (With Keyword): axial mri t2 flair lesion mri findings in the brain of a patient with herpes simplex virus encephalitis. mri, magnetic resonance imaging.
# ------------------------------------------
# Sample 7/313 - Processing PMC5602245_JNRP-8-143-g001.jpg
# Actual Caption:  Magnetic resonance imaging brain axial section T1-weighted image showing large sella-suprasellar mass
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging of the brain showing multiple infiltrative lesions involving bilateral optic nerves causing mass effect and mass effect
# Generated Caption (With Keyword): coronal mri t2 flair lesion magnetic resonance imaging of the brain showing a hyperintense mass in the left temporal lobe causing mass effect and mass effect
# ------------------------------------------
# Sample 8/313 - Processing PMC5319214_NRR-12-103-g002.jpg
# Actual Caption:  CTP post-processed image.The patient was a 48-year-old man, with no history of hypertension, diabetes, or heart disease. The onset time was 4 hours, with a lesion detected in the right temporal lobe. The baseline NIHSS score was 15. After thrombolytic therapy, the 24-hour NIHSS score was 9. Red areas represent the infarct core. Green areas represent the penumbra. R: Right; L: left; CTP: computed tomography perfusion; NIHSS: National Institution of Health Stroke Scale.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): contrast - enhanced axial ct scan of the brain of patient k. i. of 71 years old ; hypodense ring - enhancing lesion ( arrow
# Generated Caption (With Keyword): axial mri t2 flair lesion contrast - enhanced axial view of the brain of patient k. i. of 71 years old ; hypodense lesion in
# ------------------------------------------
# Sample 9/313 - Processing PMC4100395_CRIHEM2014-161952.001.jpg
# Actual Caption:  MRI of the brain showed a large mass in the left frontal area T2/FLAIR. Mild surrounding vasogenic edema and mass effect.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): axial t2 - weighted brain mri showing a large intracerebral hematoma ( ich ) in the left frontal lobe with midline shift.
# Generated Caption (With Keyword): axial mri t2 flair lesion on the second day of admission showing a large cerebral infarction ( arrow ) associated with a large hemorrhagic contusion in the right
# ------------------------------------------
# Sample 10/313 - Processing PMC4752371_cureus-0008-000000000456-i01.jpg
# Actual Caption:  Initial MRI of the brain with and without contrast.A large right frontal lobe intra-axial mass with mass effect upon the right ventricular system and a leftward midline shift of approximately 1.3 cm is shown.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'tumor', 'right', 'Meduloblastoma']
# Generated Caption (No Keyword): mri brain t1wi + contrast showing a large left fronto - parietal heterogenously enhancing mass with surrounding vasogenic edema
# Generated Caption (With Keyword): axial mri t2 flair tumor right meduloblastoma brain lesion in the left frontal lobe
# ------------------------------------------
# Sample 11/313 - Processing PMC3166780_CRIM2011-258910.001.jpg
# Actual Caption:  Axial section through the brainstem at the nerve root entry zone of the left trigeminal nerve with an illustration of the location of the 50% isodose line for gamma knife radiation treatment planning. This was the treatment location for the first and second gamma knife procedures.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'CT', 'lesion']
# Generated Caption (No Keyword): coronal contrast enhanced t1w image of brain demonstrates hyperintensity of the medial temporal lobe ( white arrow ) associated with increased signal intensity in the ambient cis
# Generated Caption (With Keyword): sagittal ct lesion coronal image of brain of 17 - year - old male, who presented with seizure, shows thinning of superior cerebellar peduncle (
# ------------------------------------------
# Sample 12/313 - Processing PMC4240937_IJNL-13-177-g003.jpg
# Actual Caption:  Brain magnetic resonance imaging, T1-weighted image showing ring-like enhancement of the active plaque
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): t1 - weighted magnetic resonance image of the patient's brain in axial section showing cortical atrophy and ex - vacuo ventricular enlargement.
# Generated Caption (With Keyword): axial mri t2 flair lesion this image shows a contrast - enhancing lesion in the right parietal lobe in the close proximity to the cavernous sinus.
# ------------------------------------------
# Sample 13/313 - Processing PMC2917440_1752-1947-4-217-3.jpg
# Actual Caption:  Brain axial T2W magnetic resonance imaging at the level of the midbrain. High signal around the Aqueduct of Sylvius (arrow).
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): transverse t2 - weighted mri image at the level of the midbrain shows the “ molar tooth sign ” due to a descent of the brainstem. the brainstem
# Generated Caption (With Keyword): axial mri t2 flair lesion transverse scan at the level of the midbrain. the lesion shows high signal intensity ( arrow ) in the right temporal lobe.
# ------------------------------------------
# Sample 14/313 - Processing PMC4977395_CRINM2016-5720319.001.jpg
# Actual Caption:  MRI brain T2 axial FLAIR sequence showed hyperintensities in the left thalamus and right mesial occipital lobe.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain mri flair, axial view. hyperintense lesions in the bilateral medial temporal and hippocampi.
# Generated Caption (With Keyword): axial mri t2 flair lesion hyperintensity in the bilateral occipital and parietal lobes.
# ------------------------------------------
# Sample 15/313 - Processing PMC3177787_crn0003-0172-f03.jpg
# Actual Caption:  MRI axial T2-weighted image identifying increased signal intensity at the left temporal lobe (arrow). Image contrast brightened.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri of the brain ( axial view ) showing multiple ring - enhancing lesions ( arrows ) involving both cerebral hemispheres.
# Generated Caption (With Keyword): axial mri t2 flair lesion the right medulla with hyperintense signal in the medulla ( arrow ).
# ------------------------------------------
# Sample 16/313 - Processing PMC5488577_JNRP-8-461-g002.jpg
# Actual Caption:  Magnetic resonance imaging brain (three-dimensional constructive interference in steady-state sequences) showing the anterior inferior cerebellar artery (black arrow) abutting the root entry zone of the facial nerve (white arrow) on the right side with no evidence of any mass lesions
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging of brain showing single ring enhancing lesion in the left parieto - occipital region
# Generated Caption (With Keyword): sagittal mri t2 flair lesion magnetic resonance imaging of brain showing demyelination of the left pons
# ------------------------------------------
# Sample 17/313 - Processing PMC4427138_crn-0007-0078-g02.jpg
# Actual Caption:  MRI of the brain: T1 coronal post-contrast sequence demonstrating faint bilateral optic nerve enhancement.
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): coronal t1 - weighted post - contrast magnetic resonance imaging image showing an enhancing mass in the right frontoparietal region.
# Generated Caption (With Keyword): coronal mri t2 flair lesion coronal magnetic resonance imaging ( mri ) of the brain showing a well - defined extra - axial mass in the
# ------------------------------------------
# Sample 18/313 - Processing PMC5699006_IJCCM-21-772-g001.jpg
# Actual Caption:  Brain MRI of FLAIR in 25 year old female with eclampsia demonstrating involvement of frontal and occipital lobes along with bilateral basal ganglion
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain mri - increased signal in t2 - weighted images in the withe matter territories adjacent to the lateral ventricles bodies and subcortical zone
# Generated Caption (With Keyword): axial mri t2 flair lesion brain mri in a 42 - year - old female with anti - nmda receptor encephalitis shows bilateral symmetrical high - signal lesions
# ------------------------------------------
# Sample 19/313 - Processing PMC3183528_IJEM-15-255-g002.jpg
# Actual Caption:  Pre-operative Magnetic Resonance imaging of brain showing hypothalamic hamartoma
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'normal']
# Generated Caption (No Keyword): mri of the brain showing lissencephaly with band heterotopia and agenesis of corpus callosum
# Generated Caption (With Keyword): sagittal mri t2 flair normal rosenthal cerebri cerebrum cerebrum ( 1 ) and sellar atrophy.
# ------------------------------------------
# Sample 20/313 - Processing PMC2811971_AIAN-12-12-g004.jpg
# Actual Caption:  One week after a febrile illness, a 55 year old man developed neurogenic dysphagia accompanied by ataxia and drowsiness. Clinical examination revealed ophthalmoplegia, cerebellar signs and sluggish deep tendon reflexes. MRI of the brain showed a single hyperintense lesion in the pons, On T2 W images which moderately enhanced with contrast. He rapidly recovered following intravenous steroids
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): normal brainstem in magnetic resonance imaging brain sagittal section ( t2 - weighted image )
# Generated Caption (With Keyword): sagittal mri t2 flair lesion normal brainstem in a 45 - year - old male patient with intractable epilepsy.
# ------------------------------------------
# Sample 21/313 - Processing PMC4640609_1400074-F2.jpg
# Actual Caption:  Across-group aPFC activity (local maxima, 30 62 −4) for motivationally incongruent versus congruent trials within Brodmann area 10.The image is thresholded at P < 0.05 (uncorrected) for visualization purposes. No other clusters reached significance for the comparison between incongruent and congruent responses in the whole group (that is, none reached whole-brain FWE correction). aPFC activity did not differ between substance groups.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): whole - brain maps illustrate smaller gray matter volumes in patients with borderline personality disorder ( bpd - ptsd ) compared to controls. the areas involved in the
# Generated Caption (With Keyword): axial mri t2 flair lesion whole - brain analysis. regions of interest ( rois ) in the hippocampus, amygdala, and temporal lobe. the
# ------------------------------------------
# Sample 22/313 - Processing PMC2292499_247_2007_538_Fig9_HTML.jpg
# Actual Caption:  Brain edema. Coronal sonogram in a 7-day-old infant with group B streptococcus meningitis shows generalized edema with compression of lateral ventricles and sulci and diffuse increased heterogeneity of the cerebral hemispheres
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): ultrasonography showing ascites formation and presence of multiple echogenic lesions over the parietal peritoneum
# Generated Caption (With Keyword): axial mri t2 flair lesion showing ascites formation and formation of a parietal peritoneum cyst with thickened parietal peritoneum
# ------------------------------------------
# Sample 23/313 - Processing PMC4334639_gr1.jpg
# Actual Caption:  MRI Brain (T2w image) scan shows residual tumor.
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): coronal t2 - weighted magnetic resonance image showing a hyperintense signal in the right frontal lobe anteriorly, with extension into the right temporal lobe.
# Generated Caption (With Keyword): coronal mri t2 flair lesion coronal image showing hyperintense signal in the right temporal lobe with extension into the left temporal lobe.
# ------------------------------------------
# Sample 24/313 - Processing PMC4777028_GJHS-4-184-g004.jpg
# Actual Caption:  Axial brain ct showing anterior falx calification
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computed tomography of the brain, axial view showing subdural hematomas at the right frontal region.
# Generated Caption (With Keyword): axial ct lesion post - operative ct scan of the brain showing recurrence of the tumour.
# ------------------------------------------
# Sample 25/313 - Processing PMC4896129_gr4.jpg
# Actual Caption:  68-year-old man with a dural arteriovenous fistula of the superior sagittal sinus. Anterior-posterior image of distal right external carotid artery injection demonstrating supply to the superior sagittal sinus fistula from a large superficial temporal artery branch as well as right middle meningeal artery branches. Note filling of the superior sagittal sinus as well as several cortical veins (arrows) indicating the presence of cortical venous reflux.
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): 68 - year - old man with a dural arteriovenous fistula of the superior sagittal sinus. lateral view of left external carotid artery injection shows both middle mening
# Generated Caption (With Keyword): coronal mri t2 flair lesion 68 - year - old man with a dural arteriovenous fistula of the superior sagittal sinus. the left external carotid artery
# ------------------------------------------
# Sample 26/313 - Processing PMC5379785_AJNS-12-123-g003.jpg
# Actual Caption:  T1WI shows hyperintense mass in the region of foramen of Monro extending superiorly into the frontal lobe
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'tumor', 'left', 'Astrocitoma']
# Generated Caption (No Keyword): mri t2 weighted image of brain shows large isointense, well - defined mass lesion in right parieto - occipital region
# Generated Caption (With Keyword): sagittal mri t2 flair tumor left astrocitoma mri of brain and sellar region showing large pituitary macroadenoma, isointense to cerebrospinal fluid
# ------------------------------------------
# Sample 27/313 - Processing PMC2778176_IJE2009-931057.001.jpg
# Actual Caption:  Skull radiograph of patient 1 taken on 13 days of age. White arrow indicates the calcification at right parietal region.
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): anteroposterior skull radiograph showing a multicystic lesion with slightly sclerotic margin in the right parietal region.
# Generated Caption (With Keyword): coronal mri t2 flair lesion anteroposterior skull radiograph showing multicystic lesion in the left parietal region, associated with significant outward bulging of the outer table
# ------------------------------------------
# Sample 28/313 - Processing PMC4738675_OJO-8-211-g006.jpg
# Actual Caption:  Diffusion weighted scan of the magnetic resonance imaging brain showing no restriction of diffusion suggestive of lesions being vasogenic edema rather than infarcts
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): diffusion - weighted magnetic resonance imaging brain showing restricted diffusion in the left temporal lobe.
# Generated Caption (With Keyword): axial mri t2 flair lesion diffusion - weighted images showing hyperintensity in the brain in a patient with herpes simplex virus encephalitis.
# ------------------------------------------
# Sample 29/313 - Processing PMC3928351_jkns-55-51-g002.jpg
# Actual Caption:  CT scan of the brain 48-hours after the head injury.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): ct scan brain plain showing left temporo - parietal subdural hematoma
# Generated Caption (With Keyword): axial ct lesion subdural hematoma revealed a right frontotemporoparietal acute subdural hemorrhage with a contusion of left temporal lobe
# ------------------------------------------
# Sample 30/313 - Processing PMC4347797_iranjradiol-11-04-10107-g004.jpg
# Actual Caption:  Axial T1W MRI without contrast shows hyperintensities in the parietal sulci indicating leptomeningeal involvement.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T1', 'normal']
# Generated Caption (No Keyword): brain mri - increased signal in t1 - weighted images in the withe matter territories adjacent to the lateral ventricles bodies and subcortical zone
# Generated Caption (With Keyword): axial mri t1 normal brain - weighted images showing hyperintensities in bilateral putamens ( white arrows )
# ------------------------------------------
# Sample 31/313 - Processing PMC5097145_edmcr-2016-160066-g001.jpg
# Actual Caption:  MRI scan showing a multifocal intracranial mass, with lesions in the anterior part of the corpus callosum, extending inferiorly on the septum pellucidum and columns of the fornices, adjacent foci of subependymal enhancing tumour in the heads of the caudate nuclei and anterior part of the left thalamus, tumour in the pineal region, inferior third ventricle and roof of the fourth ventricle.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'tumor', 'left', 'Meduloblastoma']
# Generated Caption (No Keyword): mri of brain. t1 sagittal cut showing isointense to hypo intense lesion in the left parieto - occipital region suggestive of haemorrhage.
# Generated Caption (With Keyword): sagittal mri t2 flair tumor left meduloblastoma mri of brain.
# ------------------------------------------
# Sample 32/313 - Processing PMC5409399_AJNS-12-314-g001.jpg
# Actual Caption:  Computerized tomography brain axial view showing cyst in the pineal region
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): brain computed tomography scan of the first patient at the age of 3. 5 months. the axial section of the brain ct scan shows bilateral microcep
# Generated Caption (With Keyword): axial ct lesion the brain computed tomography scan of the first patient performed in february 2008 shows a bilateral, well - defined, csf cyst surrounded by a
# ------------------------------------------
# Sample 33/313 - Processing PMC3232526_IPC-6-11-g001.jpg
# Actual Caption:  MRI scan of the brain showing extensive encephalomalacia in the left cerebral hemisphere
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging scan showing a tumor in the posterior part of the right temporal lobe with intracranial extension and midline shift.
# Generated Caption (With Keyword): coronal mri t2 flair lesion magnetic resonance imaging - scan showing a tumor - like mass in the right frontal lobe anteriorly, with intracranial extension into the
# ------------------------------------------
# Sample 34/313 - Processing PMC3139345_JNRP-1-125-g001.jpg
# Actual Caption:  CT brain (axial view) showing a hypodense lesion in the right frontal lobe
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): ct brain axial cut showing absence of vermis
# Generated Caption (With Keyword): axial ct lesion brain ct scan showing left cerebellar infarct
# ------------------------------------------
# Sample 35/313 - Processing PMC3356966_JPP-3-194-g001.jpg
# Actual Caption:  CT brain—showing cortical venous thrombosis
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): a contrast ct image of the brain shows multiple small foci of low density affecting the white matter of both hemispheres.
# Generated Caption (With Keyword): axial ct lesion a contrast - enhanced ct brain demonstrating a hyperdense, well - defined lesion in the left frontoparietal region.
# ------------------------------------------
# Sample 36/313 - Processing PMC3154863_1752-1947-5-315-3.jpg
# Actual Caption:  MRI scan with moderate degree of enhancement at the base of the skull, affecting the right occipital condyle and part of the right side of the basilar bone.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging brain t1 - weighted axial image showing a left occipital encephalomalacia
# Generated Caption (With Keyword): sagittal mri t2 flair lesion magnetic resonance imaging brain ( t2 - weighted axial ) showing a left vertebral artery infarction
# ------------------------------------------
# Sample 37/313 - Processing PMC4974992_AJNS-11-456a-g003.jpg
# Actual Caption:  Axial contrast-enhanced T1-weighted image showed a ring enhancement lesion in right temporooccipital lobe
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri of the brain showing multiple ring - enhancing lesions at bilateral parieto - occipital lobes.
# Generated Caption (With Keyword): axial mri t2 flair lesion mri of the brain showing multiple metastatic lesions involving bilateral occipital and parietal lobes
# ------------------------------------------
# Sample 38/313 - Processing PMC4375687_SaudiMedJ-36-141-g002.jpg
# Actual Caption:   Magnetic resonance imaging (flair image) showing left frontal focal area of acute ischemic infarction (arrow), and right parietal periventricular white matter old infarction (arrow)
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain with diffusion weighted imaging ( dwi ) showing acute ischemic infarct in left frontal lobe.
# Generated Caption (With Keyword): axial mri t2 flair lesion white matter lesion with hyperintensity in left frontal lobe ( arrow ).
# ------------------------------------------
# Sample 39/313 - Processing PMC3808052_JNRP-4-145-g001.jpg
# Actual Caption:  Noncontrast axial cranial CT revealing left temporoparietal acute extradural hematoma
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computerized tomography scan brain plain study showing a large hyperdense, well - defined lesion in the left temporo - parietal region with midline shift and
# Generated Caption (With Keyword): axial ct lesion plain computed tomography scan of brain on admission showing a large right - sided extra - axial hyperdense lesion with surrounding vasogenic edema
# ------------------------------------------
# Sample 40/313 - Processing PMC3690703_JCIS-3-21-g003.jpg
# Actual Caption:  Neurofibromatosis Type 2. A 34-year-old man with mild hearing loss in the left ear. Axial computed tomography (parenchymal window) of the temporal bone shows extensive choroid plexus calcifications within both atria (arrows) extending into the left temporal horn (arrowhead)
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computed tomography ( ct ) scan of the brain showing a right temporoparietal abscess ( arrow ).
# Generated Caption (With Keyword): axial ct lesion computed tomography ( ct ) of the brain. an area of low attenuation affecting the right temporal lobe is seen.
# ------------------------------------------
# Sample 41/313 - Processing PMC4176401_crn-0006-0222-g01.jpg
# Actual Caption:  Brain MRI [Siemens MAGNETOM Symphony 1.5T, T2WI (TR/TE = 1,300/69 ms)] showing mild diffuse atrophy and punctate increased signals of the frontal white matter.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain, t2w axial image showing bilateral symmetrical hyperintensities in the basal ganglia, thalami, occipital and basal ganglia
# Generated Caption (With Keyword): axial mri t2 flair lesion. figure shows a hyperintense, well - defined lesion in the right temporal lobe, with hyperintense signal intensity in the
# ------------------------------------------
# Sample 42/313 - Processing PMC4738674_OJO-8-208-g003.jpg
# Actual Caption:  Axial computerised tomography scans of the orbits showing absence of the greater wing of sphenoid (white asterix), with herniation of brain parenchyma into the left orbit (long white arrow), esotropia and kinking of the left optic nerve (short white arrow)
#
# Keyword Hasil Klasifikasi: ['coronal', 'CT', 'lesion']
# Generated Caption (No Keyword): axial computed tomography image of the orbit shows large superotemporal superotemporal rectus muscle thickness ( white arrows ) with associated soft tissue component.
# Generated Caption (With Keyword): coronal ct lesion computed tomography ( ct ) of patient 2 showing thickened right parietal bone with associated soft tissue component extending from the globe to the globe.
# ------------------------------------------
# Sample 43/313 - Processing PMC4777028_GJHS-4-184-g003.jpg
# Actual Caption:  Axial brain ct showing bilateral symmetrical basal ganglial calcification
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): brain ct scan of the patient showing bilateral basal ganglia calcification
# Generated Caption (With Keyword): axial ct lesion brain brain showing calcification of bilateral basal ganglia
# ------------------------------------------
# Sample 44/313 - Processing PMC5747170_12957_2017_1300_Fig2_HTML.jpg
# Actual Caption:  Head MRI showing multiple occupations in the right temporal, apical, and occipital lobes and in the corpus callosum
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): t2 - weighted image shows a large, hypointense, lobulated lesion in the left temporoparietal region, with hyperintensity in the
# Generated Caption (With Keyword): axial mri t2 flair lesion t2 image shows a hyperintense, well - defined lesion in the left temporoparietal region, with vasogenic
# ------------------------------------------
# Sample 45/313 - Processing PMC3081500_LJM-1-060-g001.jpg
# Actual Caption:  CT scan of Temporal bone. The thick arrow shows the bony discontinuity in the left temporal bone.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): temporal bone computed tomography ( ct ) scan showing a soft tissue mass occupying part of the external auditory canal and causing displacement of the ossicles.
# Generated Caption (With Keyword): axial mri t2 flair lesion temporal bone length measured in a patient with severe vertigo, showing an important destruction of the mastoid air cells (
# ------------------------------------------
# Sample 46/313 - Processing PMC4727638_Neurosciences-20-170-g001.jpg
# Actual Caption:  The axial view of the CT scan of the brain revealed a hypodensity mass (white arrow) in the left frontal lobe.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): a cranial computed tomography scan ( axial view ) of the patient's brain, showing extensive encephalomalacia at the bilateral frontal lobes and the right
# Generated Caption (With Keyword): axial ct lesion a cranial ct scan, without contrast, showing a hypodense lesion ( arrow ) at the left temporoparietal region (
# ------------------------------------------
# Sample 47/313 - Processing PMC3519074_JPN-7-136-g001.jpg
# Actual Caption:  MRI Axial T2 FLAIR section showing symmetrical hyperintense lesions involving subcortical and cortical locations of the bilateral frontal and parietal lobes
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain magnetic resonance image showing subcortical hematoma in left frontal lobe
# Generated Caption (With Keyword): axial mri t2 flair lesion fluid attenuation inversion recovery image showed a confluent high signal intensity in the left frontal lobe
# ------------------------------------------
# Sample 48/313 - Processing PMC3408334_1687-9856-2012-20-3.jpg
# Actual Caption:  Arachnoidal cysts. MRI Scan of the brain. Coronar, T2-weighted. Cerebellar dysplasia is seen on the right side. The arrow indicates a large arachnoidal cyst.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): axial t2 - weighted magnetic resonance imaging of the brain showing a mass in the left carotid space with soft tissue component ( arrow ).
# Generated Caption (With Keyword): sagittal mri t2 flair lesion the left temporal lobe with blood around the hematoma ( arrow ).
# ------------------------------------------
# Sample 49/313 - Processing PMC3737703_SJA-7-205-g002.jpg
# Actual Caption:  Brain magnetic resonance. The figure shows subcortical hyperintense lesions on T2-weighted sequences, with different characteristics. One draws the subcortical white matter with preservation of U fibers, at the left parietal-occipital, and the other has rounded morphology and was located in right temporal white matter. None of them suggests hemorrhagic transformation
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain flair coronal image showing left cerebellar hemisphere infarction
# Generated Caption (With Keyword): coronal mri t2 flair lesion mri brain of the patient showing left mesial temporal lesion
# ------------------------------------------
# Sample 50/313 - Processing PMC3685352_WO-17-20413-g003.jpg
# Actual Caption:  Brain MRI. No distant metastases
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain mri sagittal t1 - weighted image showing multiple hypointense lesions in the subcortical white matter of both cerebral hemispheres.
# Generated Caption (With Keyword): sagittal mri t2 flair lesion brain of patient with moyamoya disease showing multiple subcortical and cerebellar lesions.
# ------------------------------------------
# Sample 51/313 - Processing PMC3591566_SJA-6-415-g002.jpg
# Actual Caption:  CT scan of the brain showing decompressed lateral ventricleswith some blood in the occipital horns (arrows) and extra-axial fluid collection. Tip of the EVD is seen in the lateral ventricle
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computed tomography of brain showing generalized hypodensity with a smooth and irregular surface extending from the frontal to parietal regions.
# Generated Caption (With Keyword): axial ct lesion computed tomography of brain showing generalized hypodensity of the brain with effacement of sulci.
# ------------------------------------------
# Sample 52/313 - Processing PMC4421957_AJNS-10-142-g001.jpg
# Actual Caption:  Magnetic resonance imaging scan of the brain showing a well-defined round to oval space occupying lesion with marked peri-lesional white matter edema in the right fronto-parietal lobe
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging of brain t2 - weighted image showing a large lesion with varying intensities in left frontal lobe
# Generated Caption (With Keyword): axial mri t2 flair lesion brain of 45 - year - old male with a history of wilson's disease who presents with slurred speech
# ------------------------------------------
# Sample 53/313 - Processing PMC5012059_13231_2016_21_Fig1_HTML.jpg
# Actual Caption:  CT scan of the brain (axial sequence) shows an area of hyperdensity in the right frontal lobe suggestive of intracerebral hemorrhage (arrow) in a 67 year old woman who underwent right carotid endarterectomy (CEA) for the treatment of a 95 % right ICA stenosis. The patient post-operatively developed headache, photophobia and intermittent dizziness. This CT brain was done almost 24 h after the CEA. Systolic blood pressure was in the 170 s mm Hg and difficult to control as after CEA there was thought to be a clamp injury to the right carotid artery bulb. However, the patient did well clinically and at her 3 month follow up office visit, she had no residual neurological deficits
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computed tomography scan of the brain showing an old left occipital infarct ( arrow )
# Generated Caption (With Keyword): axial ct lesion ct scan of the brain showing acute cerebral infarction in the left parieto - occipital region ( arrow )
# ------------------------------------------
# Sample 54/313 - Processing PMC3036638_1752-1947-5-24-3.jpg
# Actual Caption:  Magnetic resonance angiogram of the brain demonstrating normal patency of bilateral internal carotid arteries, anterior cerebral arteries, middle cerebral arteries, posterior cerebral arteries, and vertebrobasilar arteries.
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'tumor', 'left', 'Neurocitoma']
# Generated Caption (No Keyword): mra brain showing multiple sites of infarction in the left occipital and parietal lobes bilaterally.
# Generated Caption (With Keyword): coronal mri t2 flair tumor left neurocitoma mra mra brain performed on day 5 with extensive peritumoral edema.
# ------------------------------------------
# Sample 55/313 - Processing PMC5007393_kjr-17-664-g009.jpg
# Actual Caption:  Coronal non-contrast image from brain CT assessment of frequent falls.Bilateral bands of hyperdensity that do not conform to insertions of extra-ocular muscles, are consistent with prior bilateral scleral bands for treatment of retinal detachment. However, characteristic concavity at site of banding is not seen in this case.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): orbital ct scan showing an 18 - year - old male child with post - traumatic epidural hematoma with associated right - sided pleural effusion.
# Generated Caption (With Keyword): axial ct lesion orbital ct scan showing non - contrast image showing right orbital cellulitis with associated right - sided pleural effusion.
# ------------------------------------------
# Sample 56/313 - Processing PMC3199842_CTO-06-01-g-002.jpg
# Actual Caption:  CT-scan of the temporal bone. Good aeration. Exposed malleus-incus-conglomerate. AP: atresia plate. (Thanks to Prof. Dr. med. E. Hofmann, director of the department for diagnostic and interventional neuroradiology, Klinikum Fulda gAG)
#
# Keyword Hasil Klasifikasi: ['sagittal', 'CT', 'lesion']
# Generated Caption (No Keyword): axial computed tomography image of the temporal bone showing air within the left vestibule ( arrow ).
# Generated Caption (With Keyword): sagittal ct lesion axial image of temporal bone showing soft tissue mass in the left vestibule ( arrow ).
# ------------------------------------------
# Sample 57/313 - Processing PMC4282800_PAMJ-18-342-g002.jpg
# Actual Caption:  Axial T2WI shows fluid-fluid level within the mass and marked compression over the left cerebral peduncle of midbrain
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'tumor', 'left', 'Meningioma']
# Generated Caption (No Keyword): t2 weighted axial image of brain mri showing a hyperintense, well - defined lesion in the left temporoparietal region
# Generated Caption (With Keyword): axial mri t2 flair tumor left meningioma axial image showing a hyperintense, well - defined lesion in the right temporoparietal region with surrounding edema
# ------------------------------------------
# Sample 58/313 - Processing PMC4254080_CRIOG2014-928079.001.jpg
# Actual Caption:  Case 1. Axial FLAIR MRI: cortical-subcortical hyperintense lesions in parietal-occipital regions and in the posterior lateral left putamen.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain showing hyperintensity in the left frontal and parietal lobes.
# Generated Caption (With Keyword): axial mri t2 flair lesion mri brain showing hyperintensity in the left frontoparietal region, indicating acute stroke.
# ------------------------------------------
# Sample 59/313 - Processing PMC3168089_IJPsyM-31-77-g003.jpg
# Actual Caption:  Anatomical landmarks of orbitofrontal lobe (OFL) in lateral sagittal sections
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): sagittal t1 - weighted mri showing herniation of the brain contents through the defect ( arrows ).
# Generated Caption (With Keyword): coronal mri t2 flair lesion showing showing areas of atrophy in the right temporal lobe ( arrows ).
# ------------------------------------------
# Sample 60/313 - Processing PMC4317214_ccr30003-0057-f1.jpg
# Actual Caption:  Brain CT revealing bilateral subacute frontoparietal subdural hematomas, measuring 10mm on the left and 8mm on the right, with associated local sulcal effacement.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): ct scan of brain showing right cerebellar tonsillar herniation
# Generated Caption (With Keyword): axial ct lesion ct scan showing right frontoparietal craniotomy defect ( arrow )
# ------------------------------------------
# Sample 61/313 - Processing PMC3980561_JCVJS-4-76-g005.jpg
# Actual Caption:  T2-weighted axial MRI of the brain showing no obvious abnormality
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain mri of the second patient performed in october 2007 shows a large right frontal lobe infiltrative mass that is hyperintense to brain parenchyma
# Generated Caption (With Keyword): axial mri t2 flair lesion brain of the 39 - year - old patient with moyamoya disease shows a large left frontal lobe infiltrative area
# ------------------------------------------
# Sample 62/313 - Processing PMC3755436_CRIM.NM2013-364869.003.jpg
# Actual Caption:  MRI brain T2W axial image showing hyperintense left parietal lesion.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain revealing infarction in left frontal lobe.
# Generated Caption (With Keyword): axial mri t2 flair lesion revealed a hematoma in the left frontal lobe, with peripheral edema.
# ------------------------------------------
# Sample 63/313 - Processing PMC3519079_JPN-7-148-g002.jpg
# Actual Caption:  MRI brain with FLAIR axial cut, done 3 months after the initial MRI showing resolution of the hyperintense signals seen at presentation
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain ( flair ) showing bilateral hyperintense lesions involving subcortical and deep white matter of frontal and parietal lobes
# Generated Caption (With Keyword): axial mri t2 flair lesion in the left parietal region in a patient with chronic hcv infection and cognitive changes.
# ------------------------------------------
# Sample 64/313 - Processing PMC3258753_AMS-7-3-536_F2.jpg
# Actual Caption:  Computed tomography imaging revealed hyperdense foci, corresponding to massive calcifications in the nuclei of the base of the brain, in the thymuses, as well as subcortical in the white matter of both frontal lobes
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): noncontrast brain computed tomography. numerous calcified foci are seen in the periventricular white matter of both hemispheres.
# Generated Caption (With Keyword): axial ct lesion noncontrast brain ct. calcifications of the cerebellar hemispheres are evident.
# ------------------------------------------
# Sample 65/313 - Processing PMC4633079_rb-48-05-0330-g02.jpg
# Actual Caption:  Reduction in dimensions of the cystic mass, parietal discontinuity (arrow) and voluminous ascites that was not identified at the previous study (asterisks) performed eight days ago.
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): transverse section of ct scan showing the lesion in the right parieto - occipital region with extension into the lateral ventricles, producing a mass effect on the
# Generated Caption (With Keyword): coronal mri t2 flair lesion male infant with necrotizing meningoencephalitis showing an enhancing lesion in the left parietal region ( arrow ).
# ------------------------------------------
# Sample 66/313 - Processing PMC3549408_10072_2012_965_Fig1_HTML.jpg
# Actual Caption:  Axial T1-weighted cranial MR image shows hemorrhages in temporal lobe
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T1', 'lesion']
# Generated Caption (No Keyword): brain magnetic resonance imaging shows a bilateral, well - defined, hypointense, lobulated lesion in the parieto - occipital region
# Generated Caption (With Keyword): axial mri t1 lesion brain shows a left temporo - parietal region hemorrhagic contusion
# ------------------------------------------
# Sample 67/313 - Processing PMC4067420_poljradiol-79-150-g001.jpg
# Actual Caption:  Brain MRI T1-WI axial plane of a patient with ephedrone encephalopathy: symmetrical signal increase in globi pallidi.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T1', 'lesion']
# Generated Caption (No Keyword): brain mri - increased signal in flair images in the withe matter territories adjacent to the lateral ventricles bodies and subcortical zone
# Generated Caption (With Keyword): axial mri t1 lesion brain bifrontal lobe acute subdural hemorrhage.
# ------------------------------------------
# Sample 68/313 - Processing PMC2621405_tcrm-4-1143f3.jpg
# Actual Caption:  Postoperative brain computed tomography scan 6 weeks after abscess drainage and antibiotic therapy confirms obvious shrinkage of cavities and exvacuum ventriculomegaly.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): computed tomography scan of the brain showing a 3. 7 cm × 4. 5 cm cystic lesion in the left temporo - parietal region with surrounding
# Generated Caption (With Keyword): axial mri t2 flair lesion in a 41 - year - old woman with a history of all found on clinical examination to have painless brain abscess formation
# ------------------------------------------
# Sample 69/313 - Processing PMC2783101_1757-1626-2-145-7.jpg
# Actual Caption:  Brain MRI Angiography. Normal.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain ct. the arrow indicates a high density area in the left hemisphere of the cerebellum.
# Generated Caption (With Keyword): sagittal mri t2 flair lesion cerebral arteries.
# ------------------------------------------
# Sample 70/313 - Processing PMC5508623_gr3.jpg
# Actual Caption:  Control brain MRI 3D Axial T1 with gadolinium 10 months after surgery and prolonged antibiotic treatment, shows complete regression of the cerebellar and cerebellopontine angle abscesses, leaving on the site a thickened meningeal scar.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'tumor', 'left', 'Meduloblastoma']
# Generated Caption (No Keyword): t1 - weighted contrast enhanced axial mri image showing a heterogeneously enhancing mass in the right high parietal lobe with surrounding edema.
# Generated Caption (With Keyword): sagittal mri t2 flair tumor left meduloblastoma axial contrast enhanced t1 - weighted image showing an enhancing mass in the right cerebellopontine angle with
# ------------------------------------------
# Sample 71/313 - Processing PMC5052862_ceem-15-031f1.jpg
# Actual Caption:  Absence of acute brain parenchymal lesion upon initial computed tomography of the brain.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): axial ct scan of the brain shows left temporal arachnoid cyst with mass effect on adjacent structures.
# Generated Caption (With Keyword): axial ct lesion arachnoid cyst cyst ( 10 mm ) in the right temporal lobe
# ------------------------------------------
# Sample 72/313 - Processing PMC3475880_SNI-3-107-g002.jpg
# Actual Caption:  Noncontrasted CT brain showing bifrontal lestion with area of focal calcification
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): case 1 : ct scan brain plain done on 10th post op day showing diffuse cerebral edema with effacement of the sulci.
# ...
# ------------------------------------------
# Sample 290/313 - Processing PMC1280426_ehp0113-a00616f1.jpg
# Actual Caption:  Chasing leads on brain tumors.Information on what causes brain tumors is fragmented; however, new data may tie together clues about lead exposure and a predisposition to develop meningioma.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'tumor', 'left', 'Meningioma']
# Generated Caption (No Keyword): left transverse sinus thrombosis.
# Generated Caption (With Keyword): sagittal mri t2 flair tumor left meningioma left transverse sinus thrombosis.
# ------------------------------------------
# Sample 291/313 - Processing PMC4369642_fneur-06-00062-g003.jpg
# Actual Caption:  Post-operative CT (after hemicraniectomy) day 2. The white arrows highlight the hypodense regions of brain parenchyma in the posterior circulation which is tissue at risk for subsequent ischemic injury.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): ct brain showing left temporo - parietal subdural hematoma ( arrow ).
# Generated Caption (With Keyword): axial ct lesion brain ct showing left temporo - parietal subdural hematoma ( arrow ).
# ------------------------------------------
# Sample 292/313 - Processing PMC3214422_IJO-59-491-g013.jpg
# Actual Caption:  Case 4 – Magnetic resonance imaging of brain (sagittal section) shows a cystic lesion in the suprasellar cistern (outlined by arrows) suggestive of craniopharyngioma
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging of brain showing pituitary macroadenoma compressing the optic chiasm.
# Generated Caption (With Keyword): sagittal mri t2 flair lesion pituitary tumour showing central atrophy of pituitary gland
# ------------------------------------------
# Sample 293/313 - Processing PMC4439898_JCRPE-7-77-g2.jpg
# Actual Caption:  Axial nonenhanced computed tomography image shows hemorrhagic contusion areas in the frontal lobes bilaterally as foci of hyperdensity involving the grey matter and subcortical white matter and hyperdensities filling the subarachnoid space due to subarachnoid hemorrhage in the anterior interhemispheric fissure and sulci in the frontal lobes (arrow). In addition, intraventricular hemorrhage is seen (dashed arrow)
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'normal']
# Generated Caption (No Keyword): enhanced computed tomography scan of the brain with contrast showing multiple ring enhancing lesions ( arrows ).
# Generated Caption (With Keyword): axial ct normal axial noncontrast enhanced ct scan of the brain shows diffuse cerebral edema with bilateral haemorrhagic contusions ( arrows ).
# ------------------------------------------
# Sample 294/313 - Processing PMC4899672_gr6.jpg
# Actual Caption:  Axial brain MRI GRE sequence showing a large area of susceptibility artifact in the posterior lateral left thalamus, consistent with blood products.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'normal']
# Generated Caption (No Keyword): diffusion - weighted imaging ( dwi ) mri of the brain shows multiple small hypointense lesions ( arrows ) in the left superior temporal lobe.
# Generated Caption (With Keyword): axial mri t2 flair normal head and carotid artery infarction in a patient with pca territory infarction.
# ------------------------------------------
# Sample 295/313 - Processing PMC5559658_CG-CGCR170068F001.jpg
# Actual Caption:  Magnetic resonance imaging of a 9-cm jugular paraganglioma invading the skull base, carotid vessels, and the mastoid part of the temporal bone.
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri coronal t2w image showing multiple foci of calcification in the pituitary gland ( arrow ).
# Generated Caption (With Keyword): coronal mri t2 flair lesion mri - flair coronal image showing hyperintense signal in the right temporal lobe ( arrow ).
# ------------------------------------------
# Sample 296/313 - Processing PMC3424803_AIAN-15-214-g002.jpg
# Actual Caption:  Axial FLAIR sequence shows well-circumscribed subcortical hypointense cystic lesion in bilateral anterior temporal lobe.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging brain showing bilateral swollen caudate nuclei, head of caudate nucleus and posterior thalamus
# Generated Caption (With Keyword): axial mri t2 flair lesion image of brain of patient 2 showing bilateral extra - axial high signal lesions in bilateral frontal lobes
# ------------------------------------------
# Sample 297/313 - Processing PMC3116541_IJO-59-123-g009.jpg
# Actual Caption:  Fluorescein fundus angiogram of right eye with NA-AION, showing location of the watershed zone (arrows, WSZ, vertical dark band) in relation to the optic disc. The watershed zone is passing through the temporal part of the disc and adjacent temporal peripapillary choroid[36]
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): fluorescein angiogram of right eye with na - aion ( negative temporal artery biopsy for gca ). non - filling of the area supplied by collateral
# Generated Caption (With Keyword): coronal mri t2 flair lesion fluorescein angiogram of right eye with na - aion ( right eye ) showing normal filling of the area supplied by
# ------------------------------------------
# Sample 298/313 - Processing PMC5073395_rb-49-04-0267-g01.jpg
# Actual Caption:  Axial unenhanced brain CT scan, acquired at hospital admission, showing right-sided hyperdensity in the putamen (arrow).
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computed tomography scan of the brain showing haemorrhage in the left basal ganglia ( arrow )
# Generated Caption (With Keyword): axial ct lesion computed tomography of the brain of patient patient b. note the hypodense area ( arrow ) in the left posterior temporal lobe
# ------------------------------------------
# Sample 299/313 - Processing PMC4166847_JPN-9-172-g003.jpg
# Actual Caption:  MRI brain coronal fluid attenuated inversion recovery image showing periventricular hyperintense lesions
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): magnetic resonance imaging brain t2 flair image showing bilateral symmetrical parieto - occipital white matter hyperintensities ( white arrows )
# Generated Caption (With Keyword): coronal mri t2 flair lesion magnetic resonance imaging brain brain showing bilateral symmetrical white matter hyperintensities ( white arrows ), bilateral parieto - occipital white
# ------------------------------------------
# Sample 300/313 - Processing PMC4095648_CRIM2014-874719.002.jpg
# Actual Caption:  Axial FLAIR T2-weighted brain MRI showing a sinonasal mass involving the ethmoid/sphenoid sinuses (white arrows) with extension into the right orbit (black arrowhead).
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri of the brain demonstrating evidence of increased t2 signal in the medial temporal lobes, right greater than left.
# Generated Caption (With Keyword): axial mri t2 flair lesion mri of the brain demonstrating altered signal in the left temporal lobe.
# ------------------------------------------
# Sample 301/313 - Processing PMC3788295_AIAN-16-409-g001.jpg
# Actual Caption:  T2W MRI brain showing classical “Eye of Tiger sign”
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): t2 - weighted axial mri brain image of an 8 - year - old male child with viral encephalitis shows bilateral symmetrical hyperintensities in the head of the
# Generated Caption (With Keyword): axial mri t2 flair lesion brain in a 55 - year - old female with systemic lupus erythematosus on immunosuppression, pulsed with steroids. note that the lesions
# ------------------------------------------
# Sample 302/313 - Processing PMC4173803_amjcaserep-15-404-g006.jpg
# Actual Caption:  Axial MRI section with T1-weighted sequence with fat suppression after administration of paramagnetic contrast medium. There is high uptake of the contrast medium in the lesions in the cavernous sinus and Meckel’s cave (arrows). High uptake is also observed in the lesion in the hypothalamus (arrowhead).
#
# Keyword Hasil Klasifikasi: ['coronal', 'MRI T2 FLAIR', 'tumor', 'left', 'Meningioma']
# Generated Caption (No Keyword): post - contrast coronal t1 - weighted sequence in a 49 - year - old woman with headaches demonstrates a homogenously enhancing extra axial mass within the right
# Generated Caption (With Keyword): coronal mri t2 flair tumor left meningioma post - contrast coronal image of post - operative mri showing a contrast - enhancing mass in the right temporal lobe
# ------------------------------------------
# Sample 303/313 - Processing PMC4754592_jkns-59-69-g001.jpg
# Actual Caption:  Initial brain computed tomography obtained at admission showing a chronic subdural hemorrhage (arrowheads) over both cerebral hemispheres, which compressed the adjacent brain.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): noncontrast axial computed tomographic scan initially identifying a large left parietal hypodensity with surrounding cerebral edema.
# Generated Caption (With Keyword): axial ct lesion noncontrast ct brain revealed a left parietal - occipital hypodensity with surrounding cerebral edema.
# ------------------------------------------
# Sample 304/313 - Processing PMC4242827_10-1055-s-0034-1387182-i130060-5.jpg
# Actual Caption:   Magnetic resonance imaging brain axial T1-weighted contrast-enhancing image demonstrating dramatic improvement in the Fusarium fungal abscess after both surgical evacuation and 7 months of antifungal therapy.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri of brain showing multiple ring - enhancing lesions with edema in both cerebellar hemispheres.
# Generated Caption (With Keyword): axial mri t2 flair lesion axial view of the brain demonstrating enhancement of the left mastoid mass involving the petrous apex and left temporal bone
# ------------------------------------------
# Sample 305/313 - Processing PMC3926295_CRIM.OBGYN2014-657903.001.jpg
# Actual Caption:  MRI: hyperintense signal involving the white matter typically in occipital regions.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain mri showing bilateral cerebellar hemorrhage in the fourth ventricle.
# Generated Caption (With Keyword): sagittal mri t2 flair lesion brain mri showing a hyperintense signal in the left cerebellar hemisphere.
# ------------------------------------------
# Sample 306/313 - Processing PMC4756217_gr2.jpg
# Actual Caption:  MRI post initial procedure which shows small localised soft-tissue lesion in the right fronto-parietal region (measuring up to 1.5 cm) with no extension to the underlying bone.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): brain mri of a patient with ephedrone encephalopathy : sagittal t1 - weighted image showing hypersignal in the posterior cerebellar white matter
# Generated Caption (With Keyword): sagittal mri t2 flair lesion of the brain in a patient with a massive brain abscess.
# ------------------------------------------
# Sample 307/313 - Processing PMC3639858_1752-1947-7-107-1.jpg
# Actual Caption:  Magnetic resonance image of the brain showing the complex cystic lesion extending from the left hemipons to the thalamus.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'tumor', 'left', 'Meningioma']
# Generated Caption (No Keyword): t1 mri of brain, sagittal view showing large pituitary macroadenoma displacing the superior sagittal sinus.
# Generated Caption (With Keyword): sagittal mri t2 flair tumor left meningioma mri of brain, saggital view showing mass effect on the left clivus, producing mass effect
# ------------------------------------------
# Sample 308/313 - Processing PMC2938510_JETS-3-303b-g002.jpg
# Actual Caption:  Computed tomography of the brain showing the tip of the arrowhead reaching up to the brainstem
#
# Keyword Hasil Klasifikasi: ['sagittal', 'CT', 'lesion']
# Generated Caption (No Keyword): sagittal reformatted ct image of the skull shows a rounded craniopharyngioma with intracranial extension into the posterior fossa.
# Generated Caption (With Keyword): sagittal ct lesion sagittal reformatted ct image of the skull demonstrates a lytic lesion in the left parietal bone with displacement of the cerebellum.
# ------------------------------------------
# Sample 309/313 - Processing PMC2700610_JETS-01-126-g003.jpg
# Actual Caption:  MR T2 axial image showing contusion of the brainstem
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): t2 - weighted axial magnetic resonance image showing a mass in the left temporal lobe with surrounding edema.
# Generated Caption (With Keyword): axial mri t2 flair lesion t2 - weighted axial image showing left temporal lobe tumor with peripheral hyperintense signal
# ------------------------------------------
# Sample 310/313 - Processing PMC4842861_kjr-17-424-g002.jpg
# Actual Caption:  75-year-old man with amygdala enlargement and Rathke's cleft cyst.Sagittal 11C-methionine (Met) positron emission tomography/CT image showing no 11C-Met uptake in Rathke's cleft cyst, whereas physiological 11C-Met uptake is observed in pituitary gland in anterior part.
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computer tomography image showing the circular lesion in the left temporal region with perilesional edema.
# Generated Caption (With Keyword): axial ct lesion computer tomography image showing the circular circular lesion in the left temporal region with surrounding edema. the surrounding tissue is well maintained.
# ------------------------------------------
# Sample 311/313 - Processing PMC5116640_fmed-03-00059-g002.jpg
# Actual Caption:  T2-weighted brain MRI: Note periventricular hyperintensities in relation with CSF resorption.
#
# Keyword Hasil Klasifikasi: ['axial', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): axial t2 flair image showing hyperintensity in the right frontal and parieto - occipital white matter, with involvement of u - fibers ( broca '
# Generated Caption (With Keyword): axial mri t2 flair lesion axial section of brain showing hyperintense signal in the left parieto - occipital region, with involvement of subcortical white matter.
# ------------------------------------------
# Sample 312/313 - Processing PMC3665881_aps-40-280-g002.jpg
# Actual Caption:  Magnetic resonance image.Preoperative magnetic resonance imaging showed a well-circumscribed, unilocular 18 cm×14 cm×8 cm cystic lesion without skull or brain involvement.
#
# Keyword Hasil Klasifikasi: ['sagittal', 'MRI T2 FLAIR', 'lesion']
# Generated Caption (No Keyword): mri brain with contrast ; t1 coronal sequence demonstrating minimally hypointense lesion in the right infratemporal fossa
# Generated Caption (With Keyword): sagittal mri t2 flair lesion mri brain post - contrast. image shows single hyperintense focus in the right parietal lobe
# ------------------------------------------
# Sample 313/313 - Processing PMC5324951_AJC-16-E17-g001.jpg
# Actual Caption:  Cranial computed tomography shows location of ischemic stroke at chronic stage in left occipital lobe (white arrow)
#
# Keyword Hasil Klasifikasi: ['axial', 'CT', 'lesion']
# Generated Caption (No Keyword): computed tomography of the brain shows a serpiginous intraventricular structure ( arrow ) in the left basal ganglia ( arrowhead )
# Generated Caption (With Keyword): axial ct lesion computed tomography of the brain ( axial view ) shows a serpiginous intraventricular structure ( arrow ) with calcifications in the left basal ganglia
# ------------------------------------------

# %% [markdown]
# ## Computational Cost & Time Efficiency Analysis

# %%
import torch
from transformers import VisionEncoderDecoderModel, AutoTokenizer, ViTFeatureExtractor
from PIL import Image
import time

model_name = "bombshelll/ViT_BioMedBert_Captioning_ROCO"
device = "cuda" if torch.cuda.is_available() else "cpu"

model = VisionEncoderDecoderModel.from_pretrained(model_name).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name)
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name)

def hierarchical_classification(image_path):
    return {"Modality": "MRI", "Plane": "Axial", "Abnormality": "Tumor"}

print("Model, tokenizer, dan feature extractor berhasil diload.")
# Out:
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/encoder', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/embeddings']
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/encoder', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/embeddings']
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/encoder', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/embeddings']
# Model, tokenizer, dan feature extractor berhasil diload.
# /opt/conda/lib/python3.10/site-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %% [markdown]
# #### Without integration with Hierarchical Classification

# %%
import torch, time, numpy as np
from PIL import Image
from transformers import VisionEncoderDecoderModel, AutoTokenizer, ViTFeatureExtractor

model_name = "bombshelll/ViT_BioMedBert_Captioning_ROCO"
device = "cuda" if torch.cuda.is_available() else "cpu"
model = VisionEncoderDecoderModel.from_pretrained(model_name).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_name)
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name)
image_path = "/kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg"

image = Image.open(image_path).convert("RGB")
pixel_values = feature_extractor(images=image, return_tensors="pt").pixel_values.to(device)
torch.cuda.reset_peak_memory_stats(device) if device=="cuda" else None
start_time = time.time()
model.eval()
with torch.no_grad():
    generated_ids = model.generate(pixel_values, max_length=80, num_beams=4, no_repeat_ngram_size=3, length_penalty=2.0)
caption_no_keyword = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
end_time = time.time()
elapsed_no_keyword = end_time - start_time
latency_no_keyword = elapsed_no_keyword
throughput_no_keyword = 1 / latency_no_keyword if latency_no_keyword > 0 else float('inf')
memory_usage_no_keyword = torch.cuda.max_memory_allocated(device) / (1024**2) if device=="cuda" else "N/A"
parameter_count = sum(p.numel() for p in model.parameters())
try:
    from ptflops import get_model_complexity_info
    flops, _ = get_model_complexity_info(model, (3,224,224), as_strings=True, print_per_layer_stat=False)
except:
    flops = "N/A"

print(f"Generated Caption (No Keyword): {caption_no_keyword}")

print(f"----------------------------------------------------------------------")

print(f"Inference Time (No Keyword): {elapsed_no_keyword:.4f} seconds")
print(f"Latency: {latency_no_keyword:.4f} sec/image")
print(f"Throughput: {throughput_no_keyword:.4f} images/sec")
print(f"Memory Usage: {memory_usage_no_keyword} MB")
print(f"Parameter Count: {parameter_count}")
print(f"FLOPs: {flops}")
# Out:
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/encoder', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/embeddings']
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/encoder', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/embeddings']
# The following encoder weights were not tied to the decoder ['vision_encoder_decoder/layernorm', 'vision_encoder_decoder/encoder', 'vision_encoder_decoder/pooler', 'vision_encoder_decoder/embeddings']
# Generated Caption (No Keyword): t1 - weighted magnetic resonance image of the brain showing rim enhancing lesion in the left thalamus with surrounding edema.
# ----------------------------------------------------------------------
# Inference Time (No Keyword): 0.3714 seconds
# Latency: 0.3714 sec/image
# Throughput: 2.6923 images/sec
# Memory Usage: 999.0791015625 MB
# Parameter Count: 224270394
# FLOPs: N/A

# %%
import time
import torch
import numpy as np
import pandas as pd
import os
from PIL import Image
from tqdm import tqdm

csv_path = "/kaggle/working/cleaned_testdata.csv"
image_folder = "/kaggle/input/roco-brain/test/kaggle/working/test_images"
test_df = pd.read_csv(csv_path)

latencies = []
results = []

for index, row in tqdm(test_df.iterrows(), total=len(test_df), desc="Inference on test images"):
    image_name = row["name"]
    actual_caption = row["caption"]
    image_path = os.path.join(image_folder, image_name)

    image = Image.open(image_path).convert("RGB")
    inputs = feature_extractor(images=image, return_tensors="pt").to(device)

    if device == "cuda":
        torch.cuda.reset_peak_memory_stats(device)

    start_time = time.time()
    model.eval()
    with torch.no_grad():
        generated_ids = model.generate(
            inputs["pixel_values"],
            max_length=80,
            num_beams=4,
            no_repeat_ngram_size=3,
            length_penalty=2.0
        )
    end_time = time.time()

    latency = end_time - start_time
    latencies.append(latency)

    generated_caption = tokenizer.decode(generated_ids[0], skip_special_tokens=True)
    results.append({
        "name": image_name,
        "actual": actual_caption,
        "generated": generated_caption,
        "latency": latency
    })

avg_latency = np.mean(latencies)
throughput = len(test_df) / np.sum(latencies) if np.sum(latencies) > 0 else float('inf')

print(f"Average Inference Time: {avg_latency:.4f} seconds per image")
print(f"Throughput: {throughput:.4f} images/sec")
# Out:
# Inference on test images: 100%|██████████| 313/313 [02:08<00:00,  2.43it/s]
# Average Inference Time: 0.4005 seconds per image
# Throughput: 2.4968 images/sec

# %% [markdown]
# #### With integration with Hierarchical Classification

# %%
import time
import torch
import numpy as np
import pandas as pd
import os
from PIL import Image
from tqdm import tqdm

def inference_and_integrate(data, image_folder, model, tokenizer, feature_extractor, device="cuda"):
    results = []
    latencies = []

    for index, row in tqdm(data.iterrows(), total=len(data), desc="Inference on test images"):
        image_name = row['name']
        actual_caption = row['caption']
        image_path = os.path.join(image_folder, image_name)

        start_time = time.time()

        print(f"Sample {index + 1}/{len(data)} - Processing {image_name}")
        predicted_labels = hierarchical_classification(image_path)
        predicted_keywords = [value for value in predicted_labels.values() if value is not None]
        print(f"Actual Caption: {actual_caption}")
        print(f"Keyword Hasil Klasifikasi: {predicted_keywords}")

        image = Image.open(image_path).convert("RGB")
        inputs = feature_extractor(images=image, return_tensors="pt").to(device)

        if device == "cuda":
            torch.cuda.reset_peak_memory_stats(device)

        with torch.no_grad():
            generated_ids_no_keyword = model.generate(
                inputs["pixel_values"],
                max_length=80,
                num_beams=4,
                no_repeat_ngram_size=3,
                length_penalty=2.0
            )
        caption_no_keyword = tokenizer.decode(generated_ids_no_keyword[0], skip_special_tokens=True)
        print(f"Generated Caption (No Keyword): {caption_no_keyword}")

        keyword_prompt = " ".join(predicted_keywords)
        decoder_input_ids = tokenizer(keyword_prompt, return_tensors="pt").input_ids.to(device)

        with torch.no_grad():
            generated_ids_with_keyword = model.generate(
                inputs["pixel_values"],
                decoder_input_ids=decoder_input_ids,
                max_length=80,
                num_beams=4,
                no_repeat_ngram_size=3,
                length_penalty=2.0
            )
        caption_with_keyword = tokenizer.decode(generated_ids_with_keyword[0], skip_special_tokens=True)
        print(f"Generated Caption (With Keyword): {caption_with_keyword}")
        print(f"------------------------------------------")

        end_time = time.time()
        total_latency = end_time - start_time
        latencies.append(total_latency)

        results.append({
            "Image Name": image_name,
            "Actual Caption": actual_caption,
            "Predicted Keywords": predicted_keywords,
            "Caption Without Keywords": caption_no_keyword,
            "Caption With Keywords": caption_with_keyword,
            "Total Latency": total_latency
        })

    avg_latency = np.mean(latencies)
    throughput = len(data) / np.sum(latencies) if np.sum(latencies) > 0 else float('inf')

    print(f"Average Total Inference Time: {avg_latency:.4f} sec/image")
    print(f"Throughput: {throughput:.4f} images/sec")

    return results

csv_path = "/kaggle/working/cleaned_testdata.csv"
image_folder = "/kaggle/input/roco-brain/test/kaggle/working/test_images"
test_df = pd.read_csv(csv_path)

results = inference_and_integrate(test_df, image_folder, model, tokenizer, feature_extractor, device)

# %%
import time
import torch
import numpy as np
from PIL import Image

def inference_and_integrate_one_image(image_path, model, tokenizer, feature_extractor, device="cuda"):
    actual_caption = "Actual Caption: [Masukkan caption aktual di sini]"

    print(f"Processing {image_path}")

    start_time = time.time()

    predicted_labels = hierarchical_classification(image_path)
    predicted_keywords = [value for value in predicted_labels.values() if value is not None]
    print(f"Predicted Keywords: {predicted_keywords}")

    image = Image.open(image_path).convert("RGB")
    inputs = feature_extractor(images=image, return_tensors="pt").to(device)

    if device == "cuda":
        torch.cuda.reset_peak_memory_stats(device)

    with torch.no_grad():
        generated_ids_no_keyword = model.generate(
            inputs["pixel_values"],
            max_length=80,
            num_beams=4,
            no_repeat_ngram_size=3,
            length_penalty=2.0
        )
    caption_no_keyword = tokenizer.decode(generated_ids_no_keyword[0], skip_special_tokens=True)
    print(f"Generated Caption (No Keyword): {caption_no_keyword}")

    keyword_prompt = " ".join(predicted_keywords)
    decoder_input_ids = tokenizer(keyword_prompt, return_tensors="pt").input_ids.to(device)

    with torch.no_grad():
        generated_ids_with_keyword = model.generate(
            inputs["pixel_values"],
            decoder_input_ids=decoder_input_ids,
            max_length=80,
            num_beams=4,
            no_repeat_ngram_size=3,
            length_penalty=2.0
        )
    caption_with_keyword = tokenizer.decode(generated_ids_with_keyword[0], skip_special_tokens=True)
    print(f"Generated Caption (With Keyword): {caption_with_keyword}")

    end_time = time.time()
    total_latency = end_time - start_time

    captioning_param_count = sum(p.numel() for p in model.parameters())
    classification_param_count = (
          sum(p.numel() for p in plane_model.parameters())
        + sum(p.numel() for p in modality_model.parameters())
        + sum(p.numel() for p in abnormality_model.parameters())
        + sum(p.numel() for p in tumor_type_model.parameters())
        + sum(p.numel() for p in location_model.parameters())
    )
    total_param_count = captioning_param_count + classification_param_count

    print(f"Actual Caption: {actual_caption}")
    print(f"Inference Time: {total_latency:.4f} seconds")
    print(f"Latency: {total_latency:.4f} sec/image")
    print(f"Throughput: {1/total_latency:.4f} images/sec")
    print(f"Total Parameter Count (Captioning + Classification): {total_param_count}")

    return {
        "Image Path": image_path,
        "Actual Caption": actual_caption,
        "Predicted Keywords": predicted_keywords,
        "Caption Without Keywords": caption_no_keyword,
        "Caption With Keywords": caption_with_keyword,
        "Total Latency": total_latency,
        "Total Parameter Count": total_param_count
    }

image_path = "/kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg"
result_one = inference_and_integrate_one_image(image_path, model, tokenizer, feature_extractor, device)
print(result_one)
# Out:
# Processing /kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg
# Plane Classification: axial
# Modality: MRI
# Sequence: T1
# Abnormality Status Classification: lesion
# Predicted Keywords: ['axial', 'MRI', 'T1', 'lesion']
# Generated Caption (No Keyword): t1 - weighted magnetic resonance image of the brain showing rim enhancing lesion in the left thalamus with surrounding edema.
# Generated Caption (With Keyword): axial mri t1 lesion magnetic resonance imaging of the brain showing t1 - weighted image with contrast enhancement. the tumor appears as hyperintense signal, with
# Actual Caption: Actual Caption: [Masukkan caption aktual di sini]
# Inference Time: 1.1575 seconds
# Latency: 1.1575 sec/image
# Throughput: 0.8639 images/sec
# Total Parameter Count (Captioning + Classification): 361887158
# {'Image Path': '/kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg', 'Actual Caption': 'Actual Caption: [Masukkan caption aktual di sini]', 'Predicted Keywords': ['axial', 'MRI', 'T1', 'lesion'], 'Caption Without Keywords': 't1 - weighted magnetic resonance image of the brain showing rim enhancing lesion in the left thalamus with surrounding edema.', 'Caption With Keywords': 'axial mri t1 lesion magnetic resonance imaging of the brain showing t1 - weighted image with contrast enhancement. the tumor appears as hyperintense signal, with', 'Total Latency': 1.1574840545654297, 'Total Parameter Count': 361887158}

# %% [markdown]
# ## BLEU Evaluation

# %%
# !pip install nltk
# !pip install git+https://github.com/salaniz/pycocoevalcap
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.4)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting git+https://github.com/salaniz/pycocoevalcap
#   Cloning https://github.com/salaniz/pycocoevalcap to /tmp/pip-req-build-recri017
#   Running command git clone --filter=blob:none --quiet https://github.com/salaniz/pycocoevalcap /tmp/pip-req-build-recri017
#   Resolved https://github.com/salaniz/pycocoevalcap to commit a24f74c408c918f1f4ec34e9514bc8a76ce41ffd
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pycocotools>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from pycocoevalcap==1.2) (2.0.8)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (3.7.5)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from pycocotools>=2.0.2->pycocoevalcap==1.2) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools>=2.0.2->pycocoevalcap==1.2) (1.16.0)

# %%
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd
from statistics import mean

def evaluate_bleu(csv_file):
    """
    Evaluate BLEU scores for captions in the CSV file.

    Args:
        csv_file (str): Path to the CSV file with columns:
                        - "Actual Caption"
                        - "Caption Without Keywords"
                        - "Caption With Keywords"

    Returns:
        dict: Dictionary containing average BLEU scores for captions without and with keywords.
    """
    df = pd.read_csv(csv_file)

    bleu_scores_no_keyword = []
    bleu_scores_with_keyword = []

    for _, row in df.iterrows():
        actual_caption = str(row['Actual Caption']).lower().split()
        caption_no_keyword = str(row['Caption Without Keywords']).lower().split()
        caption_with_keyword = str(row['Caption With Keywords']).lower().split()

        bleu_scores_no_keyword.append(sentence_bleu([actual_caption], caption_no_keyword))
        bleu_scores_with_keyword.append(sentence_bleu([actual_caption], caption_with_keyword))

    results = {
        "Average BLEU (No Keyword)": mean(bleu_scores_no_keyword),
        "Average BLEU (With Keyword)": mean(bleu_scores_with_keyword),
    }

    return results

csv_file = "/kaggle/working/inference_and_integration_results.csv"
results = evaluate_bleu(csv_file)

print("Evaluation Results:")
for metric, score in results.items():
    print(f"{metric}: {score:.4f}")
# Out:
# Evaluation Results:
# Average BLEU (No Keyword): 0.2979
# Average BLEU (With Keyword): 0.3348
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %% [markdown]
# ## METEOR Evaluation

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# !pip install nltk --upgrade

import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.4)
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.4)
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.translate.meteor_score import meteor_score
from nltk.tokenize import word_tokenize
import pandas as pd
from statistics import mean
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')

def evaluate_meteor(csv_file):
    try:
        df = pd.read_csv(csv_file)
    except Exception as e:
        return f"Failed to load CSV file: {e}"

    meteor_scores_no_keyword = []
    meteor_scores_with_keyword = []

    try:
        for _, row in df.iterrows():
            actual_caption = word_tokenize(str(row['Actual Caption']).lower())
            caption_no_keyword = word_tokenize(str(row['Caption Without Keywords']).lower())
            caption_with_keyword = word_tokenize(str(row['Caption With Keywords']).lower())

            meteor_scores_no_keyword.append(meteor_score([actual_caption], caption_no_keyword))
            meteor_scores_with_keyword.append(meteor_score([actual_caption], caption_with_keyword))
    except Exception as e:
        return f"Error processing rows in CSV file: {e}"

    results = {
        "Average METEOR (No Keyword)": mean(meteor_scores_no_keyword),
        "Average METEOR (With Keyword)": mean(meteor_scores_with_keyword),
    }

    return results

csv_file = "/kaggle/working/inference_and_integration_results.csv"

results = evaluate_meteor(csv_file)

print("Evaluation Results:")
if isinstance(results, dict):
    for metric, score in results.items():
        print(f"{metric}: {score:.4f}")
else:
    print(results)
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Evaluation Results:
# Average METEOR (No Keyword): 0.1865
# Average METEOR (With Keyword): 0.1614

# %% [markdown]
# # Model-Model Pembanding

# %% [markdown]
# ## BLIP

# %%
import torch
from transformers import BlipProcessor, BlipForConditionalGeneration
import pandas as pd
import os
from PIL import Image

blip_model_name = "bombshelll/roco-blip"
device = "cuda" if torch.cuda.is_available() else "cpu"

blip_processor = BlipProcessor.from_pretrained(blip_model_name)
blip_model = BlipForConditionalGeneration.from_pretrained(blip_model_name).to(device)
blip_model.eval()

csv_path = "/kaggle/input/cleanedtestdata/cleaned_testdata.csv"
image_folder = "/kaggle/input/roco-brain/test/kaggle/working/test_images"

test_df = pd.read_csv(csv_path)

def generate_caption_blip(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = blip_processor(images=image, return_tensors="pt").to(device)

    with torch.no_grad():
        generated_ids = blip_model.generate(**inputs)

    return blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

blip_results = []
for _, row in test_df.iterrows():
    image_path = os.path.join(image_folder, row["name"])
    actual_caption = row["caption"]

    generated_caption = generate_caption_blip(image_path)

    blip_results.append({"name": row["name"], "actual": actual_caption, "blip_generated": generated_caption})

blip_results_df = pd.DataFrame(blip_results)
blip_output_path = "/kaggle/working/blip_results.csv"
blip_results_df.to_csv(blip_output_path, index=False)

print(f"BLIP results saved to {blip_output_path}")
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# BLIP results saved to /kaggle/working/blip_results.csv

# %%
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd

blip_output_path = "/kaggle/working/blip_results.csv"

blip_results_df = pd.read_csv(blip_output_path)

def compute_bleu(reference_caption, generated_caption):
    reference_tokens = reference_caption.split()
    generated_tokens = generated_caption.split()
    return sentence_bleu([reference_tokens], generated_tokens)

blip_scores = [compute_bleu(row["actual"], row["blip_generated"]) for _, row in blip_results_df.iterrows()]

average_blip_bleu = sum(blip_scores) / len(blip_scores)
print(f"Average BLEU Score (BLIP): {average_blip_bleu:.4f}")
# Out:
# Average BLEU Score (BLIP): 0.2425
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
import time
import torch
import numpy as np
from PIL import Image

image_path = "/kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg"

image = Image.open(image_path).convert("RGB")
inputs = blip_processor(images=image, return_tensors="pt").to(device)

if device == "cuda":
    torch.cuda.reset_peak_memory_stats(device)

start_time = time.time()
with torch.no_grad():
    generated_ids = blip_model.generate(**inputs)
end_time = time.time()

elapsed_time = end_time - start_time
latency = elapsed_time
throughput = 1 / latency if latency > 0 else float('inf')
memory_usage = torch.cuda.max_memory_allocated(device) / (1024**2) if device=="cuda" else "N/A"
parameter_count = sum(p.numel() for p in blip_model.parameters())

try:
    from ptflops import get_model_complexity_info
    flops, _ = get_model_complexity_info(blip_model, (3, 384, 384), as_strings=True, print_per_layer_stat=False)
except Exception as e:
    flops = "N/A"

caption = blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

print(f"Image Path: {image_path}")
print(f"Generated Caption (BLIP): {caption}")

print(f"----------------------------------------------------------------------")

print(f"Inference Time (BLIP): {elapsed_time:.4f} seconds")
print(f"Latency: {latency:.4f} sec/image")
print(f"Throughput: {throughput:.4f} images/sec")
print(f"Memory Usage: {memory_usage} MB")
print(f"Parameter Count: {parameter_count}")
print(f"FLOPs: {flops}")
# Out:
# Image Path: /kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg
# Generated Caption (BLIP): brain mri with gadolinium - meningeal enhancement is clearly seen, due to intra
# ----------------------------------------------------------------------
# Inference Time (BLIP): 0.3293 seconds
# Latency: 0.3293 sec/image
# Throughput: 3.0364 images/sec
# Memory Usage: 9923.02685546875 MB
# Parameter Count: 247414076
# FLOPs: N/A

# %% [markdown]
# ## GIT

# %%
import torch
from transformers import AutoProcessor, AutoModelForCausalLM
import pandas as pd
import os
from PIL import Image

git_model_name = "bombshelll/git-finetuning-rocobrain"

git_processor = AutoProcessor.from_pretrained(git_model_name)
device = "cuda" if torch.cuda.is_available() else "cpu"
git_model = AutoModelForCausalLM.from_pretrained(git_model_name).to(device)
git_model.eval()

def generate_caption_git(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = git_processor(images=image, return_tensors="pt").to(device)

    with torch.no_grad():
        generated_ids = git_model.generate(**inputs)

    return git_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

git_results = []
for _, row in test_df.iterrows():
    image_path = os.path.join(image_folder, row["name"])
    actual_caption = row["caption"]

    generated_caption = generate_caption_git(image_path)

    git_results.append({"name": row["name"], "actual": actual_caption, "git_generated": generated_caption})

git_results_df = pd.DataFrame(git_results)
git_output_path = "/kaggle/working/git_results.csv"
git_results_df.to_csv(git_output_path, index=False)

print(f"GIT results saved to {git_output_path}")
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1220: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# GIT results saved to /kaggle/working/git_results.csv

# %%
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd

git_output_path = "/kaggle/working/git_results.csv"

git_results_df = pd.read_csv(git_output_path)

def compute_bleu(reference_caption, generated_caption):
    reference_tokens = reference_caption.split()
    generated_tokens = generated_caption.split()
    return sentence_bleu([reference_tokens], generated_tokens)

git_scores = [compute_bleu(row["actual"], row["git_generated"]) for _, row in git_results_df.iterrows()]

average_git_bleu = sum(git_scores) / len(git_scores)
print(f"Average BLEU Score (GIT): {average_git_bleu:.4f}")
# Out:
# Average BLEU Score (GIT): 0.2289
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
def generate_caption_git(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = git_processor(images=image, return_tensors="pt").to(device)
    with torch.no_grad():
        generated_ids = git_model.generate(**inputs)
    return git_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

latencies = []
git_results = []

for _, row in test_df.iterrows():
    image_path_full = os.path.join(image_folder, row["name"])
    actual_caption = row["caption"]

    start_time = time.time()
    generated_caption = generate_caption_git(image_path_full)
    end_time = time.time()

    latency = end_time - start_time
    latencies.append(latency)

    git_results.append({
        "name": row["name"],
        "actual": actual_caption,
        "git_generated": generated_caption,
        "latency": latency
    })

avg_latency = sum(latencies) / len(latencies)
throughput = len(test_df) / sum(latencies) if sum(latencies) > 0 else float('inf')

print(f"Average Inference Time (GIT): {avg_latency:.4f} sec/image")
print(f"Throughput (GIT): {throughput:.4f} images/sec")
# Out:
# Average Inference Time (GIT): 0.3271 sec/image
# Throughput (GIT): 3.0567 images/sec

# %%
import time
import torch
import numpy as np
from PIL import Image

image_path = "/kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg"

image = Image.open(image_path).convert("RGB")
inputs = git_processor(images=image, return_tensors="pt").to(device)

if device == "cuda":
    torch.cuda.reset_peak_memory_stats(device)

start_time = time.time()
with torch.no_grad():
    generated_ids = git_model.generate(**inputs)
end_time = time.time()

elapsed_time = end_time - start_time
latency = elapsed_time
throughput = 1 / latency if latency > 0 else float('inf')
memory_usage = torch.cuda.max_memory_allocated(device) / (1024**2) if device == "cuda" else "N/A"
parameter_count = sum(p.numel() for p in git_model.parameters())

try:
    from ptflops import get_model_complexity_info
    flops, _ = get_model_complexity_info(git_model, (3, 384, 384), as_strings=True, print_per_layer_stat=False)
except Exception as e:
    flops = "N/A"

caption = git_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

print(f"Image Path: {image_path}")
print(f"Generated Caption (GIT): {caption}")
print(f"----------------------------------------------------------------------")
print(f"Inference Time (GIT): {elapsed_time:.4f} seconds")
print(f"Latency: {latency:.4f} sec/image")
print(f"Throughput: {throughput:.4f} images/sec")
print(f"Memory Usage: {memory_usage} MB")
print(f"Parameter Count: {parameter_count}")
print(f"FLOPs: {flops}")
# Out:
# Image Path: /kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg
# Generated Caption (GIT): resonance brain performed episode blindness cebella athy., resonance. mri magnetic imaging
# ----------------------------------------------------------------------
# Inference Time (GIT): 0.3347 seconds
# Latency: 0.3347 sec/image
# Throughput: 2.9876 images/sec
# Memory Usage: 6035.37109375 MB
# Parameter Count: 176619066
# FLOPs: N/A

# %% [markdown]
# ## VIT + GPT2

# %%
import torch
from transformers import VisionEncoderDecoderModel, ViTImageProcessor, AutoTokenizer
import pandas as pd
import os
from PIL import Image

vit_gpt2_model_name = "bombshelll/vit-gpt2-finetuning-rocobrain"

vit_processor = ViTImageProcessor.from_pretrained(vit_gpt2_model_name)
tokenizer = AutoTokenizer.from_pretrained(vit_gpt2_model_name)

device = "cuda" if torch.cuda.is_available() else "cpu"
vit_model = VisionEncoderDecoderModel.from_pretrained(vit_gpt2_model_name).to(device)
vit_model.eval()

def generate_caption_vit(image_path):
    image = Image.open(image_path).convert("RGB")
    inputs = vit_processor(images=image, return_tensors="pt").to(device)

    with torch.no_grad():
        generated_ids = vit_model.generate(pixel_values=inputs["pixel_values"], max_length=50)

    return tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

test_df = pd.read_csv("/kaggle/input/cleanedtestdata/cleaned_testdata.csv")
image_folder = "/kaggle/input/roco-brain/test/kaggle/working/test_images"

vit_results = []
for _, row in test_df.iterrows():
    image_path = os.path.join(image_folder, row["name"])
    actual_caption = row["caption"]

    generated_caption = generate_caption_vit(image_path)

    vit_results.append({"name": row["name"], "actual": actual_caption, "vit_generated": generated_caption})

vit_results_df = pd.DataFrame(vit_results)
vit_output_path = "/kaggle/working/vit_gpt2_results.csv"
vit_results_df.to_csv(vit_output_path, index=False)

print(f"ViT-GPT2 results saved to {vit_output_path}")

# %%
from nltk.translate.bleu_score import sentence_bleu
import pandas as pd

vit_output_path = "/kaggle/working/vit_gpt2_results.csv"

vit_results_df = pd.read_csv(vit_output_path)

def compute_bleu(reference_caption, generated_caption):
    reference_caption = str(reference_caption) if pd.notna(reference_caption) else ""
    generated_caption = str(generated_caption) if pd.notna(generated_caption) else ""

    if not reference_caption.strip() or not generated_caption.strip():
        return 0.0

    reference_tokens = reference_caption.split()
    generated_tokens = generated_caption.split()

    return sentence_bleu([reference_tokens], generated_tokens)

vit_scores = [compute_bleu(row["actual"], row["vit_generated"]) for _, row in vit_results_df.iterrows()]

average_vit_bleu = sum(vit_scores) / len(vit_scores) if len(vit_scores) > 0 else 0.0
print(f"Average BLEU Score (ViT-GPT2): {average_vit_bleu:.4f}")
# Out:
# Average BLEU Score (ViT-GPT2): 0.2628
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# /opt/conda/lib/python3.10/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
import time
import torch
import numpy as np
import pandas as pd
import os
from PIL import Image
from tqdm import tqdm

latencies = []
vit_results = []

for _, row in tqdm(test_df.iterrows(), total=len(test_df), desc="ViT-GPT2 Inference"):
    image_path_full = os.path.join(image_folder, row["name"])
    actual_caption = row["caption"]

    image = Image.open(image_path_full).convert("RGB")
    inputs = vit_processor(images=image, return_tensors="pt").to(device)

    start_time = time.time()
    with torch.no_grad():
        generated_ids = vit_model.generate(pixel_values=inputs["pixel_values"], max_length=50)
    end_time = time.time()

    latency = end_time - start_time
    latencies.append(latency)

    generated_caption = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
    vit_results.append({
        "name": row["name"],
        "actual": actual_caption,
        "vit_generated": generated_caption,
        "latency": latency
    })

avg_latency = np.mean(latencies)
throughput = len(test_df) / np.sum(latencies) if np.sum(latencies) > 0 else float('inf')

print(f"Average Inference Time (ViT+GPT2): {avg_latency:.4f} sec/image")
print(f"Throughput (ViT+GPT2): {throughput:.4f} images/sec")
# Out:
# ViT-GPT2 Inference: 100%|██████████| 313/313 [02:25<00:00,  2.15it/s]
# Average Inference Time (ViT+GPT2): 0.4544 sec/image
# Throughput (ViT+GPT2): 2.2006 images/sec

# %%
import time
import torch
import numpy as np
from PIL import Image

image_path = "/kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg"

image = Image.open(image_path).convert("RGB")
inputs = vit_processor(images=image, return_tensors="pt").to(device)

if device == "cuda":
    torch.cuda.reset_peak_memory_stats(device)

start_time = time.time()
with torch.no_grad():
    generated_ids = vit_model.generate(pixel_values=inputs["pixel_values"], max_length=50)
end_time = time.time()

elapsed_time = end_time - start_time
latency = elapsed_time  
throughput = 1 / latency if latency > 0 else float('inf')
memory_usage = torch.cuda.max_memory_allocated(device) / (1024**2) if device=="cuda" else "N/A"
parameter_count = sum(p.numel() for p in vit_model.parameters())

try:
    from ptflops import get_model_complexity_info
    flops, _ = get_model_complexity_info(vit_model, (3,224,224), as_strings=True, print_per_layer_stat=False)
except Exception as e:
    flops = "N/A"

caption = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print(f"Image Path: {image_path}")
print(f"Generated Caption (ViT+GPT2): {caption}")
print(f"Inference Time (ViT+GPT2): {elapsed_time:.4f} seconds")
print(f"Latency: {latency:.4f} sec/image")
print(f"Throughput: {throughput:.4f} images/sec")
print(f"Memory Usage: {memory_usage} MB")
print(f"Parameter Count: {parameter_count}")
print(f"FLOPs: {flops}")

memory_usage_current = torch.cuda.memory_allocated(device) / (1024**2) if device=="cuda" else "N/A"
print(f"Current Memory Usage: {memory_usage_current:.2f} MB")
# Out:
# Image Path: /kaggle/input/roco-brain/test/kaggle/working/test_images/PMC3219482_crg0005-0583-f01.jpg
# Generated Caption (ViT+GPT2): upstate star ∥ apparent protocol ⁎ 71 pruritus obl ℛ ℐ ⁴æ美 infrequent е
# Inference Time (ViT+GPT2): 0.3026 seconds
# Latency: 0.3026 sec/image
# Throughput: 3.3042 images/sec
# Memory Usage: 5974.22607421875 MB
# Parameter Count: 239195904
# FLOPs: N/A
# Current Memory Usage: 5965.61 MB
